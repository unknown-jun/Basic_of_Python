# %% [markdown]
# <a href="https://colab.research.google.com/github/unknown-jun/Basic_of_Python/blob/master/04_Dev_2020.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# #58. 예외처리 이해하기 ④ (try~except Exception as e)
#
#  - 코드에서 예외가 발생하면 이에 대한 자세한 내용을 파악하는것이 중요함.
#  - 파이썬은 발생 가능한 예외에 대해 exception 객체로 미리 정의해두고 있다
#
# > http://docs.python.org/3/library/exceptions.html
#
# - 위의 사이트에 보면 여러가지 다양한 에러에 대해서 미리 에러처리를 할 수 있도록 정의의해놓은 예외들을 확인할 수 있다.

# %%
# 예제 1
try:
    x = int(input('분자의 숫자를 입력하시요'))
    y = int(input('분모의 숫자를 입력하시오'))
    print(x/y)
except:
    """ 분모에 0이나 문자를 입력해도 예외처리를 통해 에러를 방지함"""
    print('잘못된 값을 입력하고 나누기를 시도하셨습니다')
# Out:
# 분자의 숫자를 입력하시요10
# 분모의 숫자를 입력하시오0
# 잘못된 값을 입력하고 나누기를 시도하셨습니다

# %% [markdown]
# - 위의 경우에는 분모값을 입력할 때 숫자 0을 입력했을 때와 문자 a를 입력했을 때 똑같이 '잘못된 값을 입력하셔서 나누기를 시도하셨습니다'가 출력됨
# - 좀 더 구체화해서 분모값을 0을 입력하면 '0으로 나눌 수 없습니다'가 나오고 분모값으로 a를 입력하면 '잘못된 값을 입력하셨습니다'가 나오게 하고 싶다면?

# %%
# 예제 2
try:
    x = int(input('분자의 숫자를 입력하시요'))
    y = int(input('분모의 숫자를 입력하시오'))
    print(x/y)
except ZeroDivisionError:
    """ 분모에 0을 입력해도 예외처리를 통해 에러를 방지함"""
    print('0으로 나눌 수 없습니다.')
except:
    """분모에 음수나 숫자가 아닌 다른 값을 입력하는 것을 예외처리함"""
    print('잘못된 값을 입력하셨습니다')
# Out:
# 분자의 숫자를 입력하시요10
# 분모의 숫자를 입력하시오ㅁ
# 잘못된 값을 입력하셨습니다

# %% [markdown]
# **문제 191. 숫자를 물어보게 하고 숫자를 입력하면 해당 숫자만큼 1번부터 출력되게 하는 코드를 작성하시오.**
#
# ```
# 숫자를 입력하세요: 5
#
# 1
# 2
# 3
# 4
# 5
# ```

# %%
num = int(input( '숫자를 입력하세요: ' ))

for i in range( 1, num+1 ):
    print( i )
# Out:
# 숫자를 입력하세요: 5
# 1
# 2
# 3
# 4
# 5

# %% [markdown]
# **문제 192. 위의 코드에 예외처리를 해서 숫자를 물어볼 때 문자를 입력하면 '잘못된 값을 입력하셨습니다'라고 메세지가 출력되게 하시오**

# %%
try:
    num1 = int(input( '숫자를 입력하세요: ' ))
    for i in range( 1, num1+1 ):
        print( i )
except:
    print( '잘못된 값을 입력하셨습니다' )
# Out:
# 숫자를 입력하세요: ㅁ
# 잘못된 값을 입력하셨습니다

# %% [markdown]
# - 위의 코드의 경우에는 숫자를 입력할 때 알파벳 a를 넣으면 예외처리가 되어서 '잘못된 값을 입력하셨습니다.'라고만 나옴
# > 에러에 대한 정확한 원인 파악이 어려움
# - '잘못된 값을 입력하셨습니다' 말고도 정확한 에러애 대한 원인을 파악을 하고 싶다면?

# %%
try:
    num1 = int(input( '숫자를 입력하세요: ' ))
    for i in range( 1, num1+1 ):
        print( i )
except Exception as e:
    print( '잘못된 값을 입력하셨습니다' )
    print(e)  #  에러의 발생 원인을 출력해줌
# Out:
# 숫자를 입력하세요: '
# 잘못된 값을 입력하셨습니다
# invalid literal for int() with base 10: "'"

# %% [markdown]
# #59. 특정 예외처리 이해하기 5 (try ~ except 특정 예외)
#
#  - 파이썬의 작동 상 오류가 아닌데 프로그래머의 입장에선 오류라고 판단될 시 일부러 프로그램이 작동되지 않고 오류메세지를 출력하는 경우에 사용
#
# ```
# 계산하는 프로그램
# 프로그램 코드 ........
# 프로그램 코드 ........   <-- 오류가 발생했으면 (파이썬 입장에선 오류가 아님)
# 프로그램 코드 ........  => 작동하지 않음
# 프로그램 코드 ........
# ```
# - 금융권 프로그램에서는 금액이 안 맞는 프로그램이 있다면 사고로 이어지게 되므로 금액이 맞지 않으면 프로그램을 종료하는 예외처리를 할수 있다.
#
# ```
# 실행코드
# if 어떤 조건:
#     raise Exception('예외가 발생했습니다.')    # 여기서 종료
# else:
#     실행코드
# ```

# %% [markdown]
# **문제 193. 판다스를 이용하여 emp3.csv의 데이터를 로드하는데 이름을 물어보게 하고 이름을 입력하면 해당 사원의 이름과 월급이 출력되게 하시오!**
#
# ```
# 이름을 입력하세요: scott
#
# SCOTT 3000
# ```

# %%
import pandas as pd
from google.colab import files
uploaded = files.upload()

emp = pd.read_csv('emp3.csv')
name = input('이름을 입력하세요: ')
print(emp[['ename', 'sal']][emp['ename']==name.upper()])
# Out:
#      <input type="file" id="files-9cc6c2ae-fbb3-4d5e-8bc7-b27f2728885b" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-9cc6c2ae-fbb3-4d5e-8bc7-b27f2728885b">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script src="/nbextensions/google.colab/files.js"></script>
# Saving emp3.csv to emp3 (1).csv
# 이름을 입력하세요: scott
#     ename   sal
# 11  SCOTT  3000

# %% [markdown]
# **문제 194. 위의 결과에서 월급만 출력하시오!**

# %%
import pandas as pd

emp = pd.read_csv('emp3.csv')
name = input('이름을 입력하세요: ')
print(emp['sal'][emp['ename']==name.upper()])
# Out:
# 이름을 입력하세요: scott
# 11    3000
# Name: sal, dtype: int64

# %%
import pandas as pd

emp = pd.read_csv('emp3.csv')
name = input('이름을 입력하세요: ')
result = emp['sal'][emp['ename']==name.upper()]
print(result)
print( type(result) )
# Out:
# 이름을 입력하세요: scott
# 11    3000
# Name: sal, dtype: int64
# <class 'pandas.core.series.Series'>

# %%
import pandas as pd

emp = pd.read_csv('emp3.csv')
name = input('이름을 입력하세요: ')

result = emp['sal'][emp['ename']==name.upper()].values[0]  # 값을 가지고 오는 메소드
"""emp 데이터 프레임에서 어떤 특정값을 딱 하나만 출력하려면 위와 같이 작성해줘야 함"""
print(result)
print( type(result) )
# Out:
# 이름을 입력하세요: scott
# 3000
# <class 'numpy.int64'>

# %% [markdown]
# **문제 195. 위의 코드에 사용자 정의 예외처리를 해서 월급이 고소득자는 해당사원의 월급을 볼 수 없습니다.라는 메세지가 출력되게 하시오.**
# (월급이 3000 이상인 사원들을 고소득자로 보고 작성하시오)

# %%
import pandas as pd

emp = pd.read_csv('emp3.csv')
name = input('이름을 입력하세요: ')

result = emp['sal'][emp['ename']==name.upper()].values[0]
if result >= 3000:
    raise Exception('해당 사원의 월급은 볼 수 없습니다.')  #  월급이 3000이라면 에러를 발생시켜 프로그램을 종료시킴
else:
    print(emp[['ename', 'sal']][emp['ename']==name.upper()])
# Out:
# 이름을 입력하세요: smith
#     ename  sal
# 10  SMITH  800

# %% [markdown]
# **문제 196. 위의 코드를 수정해서 이름을 물어보게 하고 이름과 직업을 출력하는 코드로 작성하는데 직업이 SALESMAN이면 "해당 사원의 정보는 볼수 없습니다." 라는 메세지가 출력되면서 프로그램이 종료되게 하시오**

# %%
import pandas as pd

emp = pd.read_csv("emp3.csv")
name = input('이름을 입력하세요: ')

result = emp['job'][emp['ename'] == name.upper()].values[0]
if result == 'SALESMAN':
    raise Exception('해당 사원의 정보는 볼 수 없습니다.')
else:
    print(emp[['ename', 'sal']][emp['ename'] == name.upper()])
# Out:
# 이름을 입력하세요: king
#   ename   sal
# 0  KING  5000

# %% [markdown]
# #60. 사용자 값 입력받기(input)
# - 파이썬 내장 함수 input은 사용자가 키보드로 입력한 값을 문자열로 return함
# - input()의 인자는 사용자 입력을 돕기 위한 안내문구나 힌트등을 표시하는 문자열이 됨

# %%
# 예
name = input('사원이름을 입력하세요: ')
num = input('숫자값을 입력하세요: ')
# Out:
# 사원이름을 입력하세요: SCOTT
# 숫자값을 입력하세요: 3000

# %% [markdown]
# **문제 197. 아래처럼 사원 이름을 물어보게 하고 사원이름을 입력하면 해당 사원의 이름과 월급이 출력되게 하시오**

# %%
import pandas as pd

name = input('사원 이름을 입력하세요: ')

emp = pd.read_csv('emp3.csv')
print(emp[['ename', 'sal']][emp['ename']==name.upper()])
# Out:
# 사원 이름을 입력하세요: scott
#     ename   sal
# 11  SCOTT  3000

# %% [markdown]
# **문제 198. 없는 사원 이름을 입력하면 "해당사원은 없습니다." 라는 메세지가 출력되게 하시오**

# %%
import pandas as pd
try:
    name = input('사원 이름을 입력하세요: ')
 
    emp = pd.read_csv('emp3.csv')
    result = emp['ename'][emp['ename']==name.upper()].values[0] 
    
    """
    이 코드에서 values[0]을 사용하면 Series(컬럼)가 아니라 값으로 출력되어 result에 담기게 됨
    없는 사원을 입력하면 result에 값을 입력되지 않게 됨
    하나의 value를 뽑아 result에 담는다. 
    잘못된 값을 가져왔을 경우엔 result에 아무런 값을 가지고 오지 못한다.
    """
    
    print(emp[['ename', 'sal']][emp['ename']==result])   # 아무런 값을 가지고 오지 못했을 때 
except LookupError:       #  LookupError 예외처리가 되어서 해당사원은 없습니다라는 메세지가 출력
    print('해당사원은 없습니다.')
# Out:
# 사원 이름을 입력하세요: ㅁ
# 해당사원은 없습니다.

# %% [markdown]
# **문제 199. 직업을 물어보게 하고 직업을 입력하면 해당 사원의 이름과 직업과 월급이 출력되게 하는 코드를 작성하는데 없는 직업을 입력하면 "해당 직업은 사원테이블에 없습니다."라는 메세지가 출력하시오**
#
# ```
# 직업을 입력하세요: SALESMAN
#
# 직업을 입력하세요: aaa
# 해당 직업은 사원 테이블에 없습니다
# ```

# %%
import pandas as pd

emp = pd.read_csv("emp3.csv")

try:
    name = input("직업을 입력하세요: ")
    result = emp[['ename', 'sal', 'job']][emp['job']== name.upper()].values[0]  
    print(emp[['ename', 'sal', 'job']][emp['job']== name.upper()]) 
    """ 
    result를 이 곳에 담으면 한명만 나오게 되지만 
    valuse[ ] 이 메소드를 쓰지 않는다면 DataFrame의 형태로 출력이 가능
    """
except LookupError:    # 없는 result의 출력값에 대한 예외처리
    print('해당 직업은 사원테이블에 없습니다')
# Out:
# 직업을 입력하세요: salesman
#     ename   sal       job
# 4  MARTIN  1250  SALESMAN
# 5   ALLEN  1600  SALESMAN
# 6  TURNER  1500  SALESMAN
# 8    WARD  1250  SALESMAN

# %% [markdown]
# #61. 자료형 확인하기 (type)
# - 파이썬의 자료형은 하나의 클래스임.
# - 파이썬은 숫자나 문자, 문자열, 리스트, 튜플, 사전, 함수 등의 각각의 하나의 클래스로 취급함
# - 코드를 작성하다가 변수 이름만 보고 이 자료가 어떤 자료형인지 확인해야 하는 경우가 있음
# > 이때 파이썬 내장함수인 type()을 활용하면 자료형을 확인할 수 있음

# %%
# 예제
numdata = 57
print( type(numdata) )

numdata2 = 57.2
print( type(numdata2) )

strdata = 'Python'
print( type(strdata) )

a = [1,2,3,4]
print( type(a) )
# Out:
# <class 'int'>
# <class 'float'>
# <class 'str'>
# <class 'list'>

# %% [markdown]
# **문제 200. dictionary 자료형을 만들고 위와 같이 type을 확인하시오**

# %%
dict = {'Fruit':['apple', 'peach', 'grape'],'veggie':['bigchoi', 'chilly'] }
print( type(dict) )
# Out:
# <class 'dict'>

# %% [markdown]
# ```
# 리스트   --> 대괄호 [ ]
# 튜플     --> 소괄호 ( )
# 딕셔너리 --> 중괄호 { }
# ```

# %% [markdown]
# #62. 나눗셈에서 나머지만 구하기 (%)
# - 나누기 연산에서 나머지만 구하는 연산을 %로 계산

# %%
# 예제
print( 12%3 )
print( 12%5 )
# Out:
# 0
# 2

# %% [markdown]
# **문제 201. 아래와 같이 두개의 숫자를 각각 물어보게 하고 아래의 메세지가 출력되게 하시오**
# ```
# 첫번째 숫자를 입력하세요: 1113
# 두번째 숫자를 입력하세요: 23
# 1113을 23으로 나누면 9가 나머지로 남습니다.
# ```

# %%
num1 = int(input('첫번째 숫자를 입력하세요: '))
num2 = int(input('두번째 숫자를 입력하세요: '))
print(f"{num1}을 {num2}로 나누면 {num1 % num2}가 나머지로 남습니다")
# Out:
# 첫번째 숫자를 입력하세요: 1113
# 두번째 숫자를 입력하세요: 23
# 1113을 23로 나누면 9가 나머지로 남습니다

# %% [markdown]
# #63. 몫과 나머지 구하기(divmod)

# %%
# 예제:
result1 , result2 = divmod(1113,23)  # divmod 함수가 출력하는 값이 2개여서 result1, result2 변수를 두개를 입력
# 몫       나머지
print(result1, '몫의 값입니다', '\n')
print(result2, '나머지의 값입니다', '\n')
print(result1, result2, '\n')
print(divmod(1113,23))
# Out:
# 48 몫의 값입니다
#
# 9 나머지의 값입니다
#
# 48 9
#
# (48, 9)

# %% [markdown]
# **문제 202. 아래와 같이 실행되게 코드를 수행하시오**
# ```
# 첫번째 숫자를 입력하시오: 1113
# 두번째 숫자를 입력하시오: 23
#
# 1113을 23으로 나눈 몫은 48이고 나머지는 9입니다.
#
# 첫번째 숫자를 입력하시오: 1113
# 두번째 숫자를 입력하시오: 0
#
# 0으로는 나눌 수 없습니다.
# ```

# %%
try:
    num1 = int(input('첫번째 숫자를 입력하시오:'))
    num2 = int(input('두번째 숫자를 입력하시오:'))
    result1, result2 = divmod(num1, num2)
    print(f"{num1}을 {num2}으로 나눈 몫은 {result1}이고 나머지는 {result2}입니다")
except ZeroDivisionError:
    print(f"{num2}으로는 나눌 수가 없습니다.")
# Out:
# 첫번째 숫자를 입력하시오:1113
# 두번째 숫자를 입력하시오:0
# 0으로는 나눌 수가 없습니다.

# %% [markdown]
# #64. Pandas를 이용한 데이터 검색
#
# - SQL, Pandas를 자유롭게 사용할 수 있어야 함
# - 두 프로그램간의 변환을 능숙히 수행할 수 있어야 함

# %%
# 예제
emp[ ['ename', 'sal']][emp['ename']=='SCOTT']
         # 컬럼               # 조건
# Out:
#     ename   sal
# 11  SCOTT  3000

# %%
uploaded = files.upload()
# Out:
#      <input type="file" id="files-273938aa-39cb-406f-b33c-89986a538340" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-273938aa-39cb-406f-b33c-89986a538340">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script src="/nbextensions/google.colab/files.js"></script>
# Saving dept3.csv to dept3.csv

# %% [markdown]
# **문제 203. dept3.csv를 판다스로 로드해서 dept 데이터 프레임 전체를 출력하시오**

# %%
dept = pd.read_csv("dept3.csv")
dept
# Out:
#    deptno       dname       loc
# 0      10  ACCOUNTING  NEW YORK
# 1      20    RESEARCH    DALLAS
# 2      30       SALES   CHICAGO
# 3      40  OPERATIONS    BOSTON

# %% [markdown]
# **문제 204. 부서위치가 DALLAS의 부서번호와 부서명(dname)을 출력하시오**

# %%
dept[['deptno', 'dname']][dept['loc']=='DALLAS']
# Out:
#    deptno     dname
# 1      20  RESEARCH

# %% [markdown]
# #65. Pandas를 이용한 조인
#
# ```
# 예제: 이름과 부서위치를 출력하시오
# SQL>
# select e.ename, d.loc
#     from emp e, dept d
#     where e.deptno = d.deptno;
# ```

# %%
emp = pd.read_csv('emp3.csv')
dept = pd.read_csv('dept3.csv')

result=pd.merge( emp, dept, on = 'deptno')
"""emp 데이터 프레임과 dept 데이터 프레임을 merge를 써서 조인시키는데 'on = deptno'
를 이용해서 연결고리가 되는 컬럼을 지정해주면 됨"""
print(result)
result[['ename', 'loc']]
# Out:
#     index  empno   ename        job  ...    comm deptno       dname       loc
# 0       1   7839    KING  PRESIDENT  ...     NaN     10  ACCOUNTING  NEW YORK
# 1       3   7782   CLARK    MANAGER  ...     NaN     10  ACCOUNTING  NEW YORK
# 2      14   7934  MILLER      CLERK  ...     NaN     10  ACCOUNTING  NEW YORK
# 3       2   7698   BLAKE    MANAGER  ...     NaN     30       SALES   CHICAGO
# 4       5   7654  MARTIN   SALESMAN  ...  1400.0     30       SALES   CHICAGO
# 5       6   7499   ALLEN   SALESMAN  ...   300.0     30       SALES   CHICAGO
# 6       7   7844  TURNER   SALESMAN  ...     0.0     30       SALES   CHICAGO
# 7       8   7900   JAMES      CLERK  ...     NaN     30       SALES   CHICAGO
# 8       9   7521    WARD   SALESMAN  ...   500.0     30       SALES   CHICAGO
# 9       4   7566   JONES    MANAGER  ...     NaN     20    RESEARCH    DALLAS
# 10     10   7902    FORD    ANALYST  ...     NaN     20    RESEARCH    DALLAS
# 11     11   7369   SMITH      CLERK  ...     NaN     20    RESEARCH    DALLAS
# 12     12   7788   SCOTT    ANALYST  ...     NaN     20    RESEARCH    DALLAS
# 13     13   7876   ADAMS      CLERK  ...     NaN     20    RESEARCH    DALLAS
#
# [14 rows x 11 columns]
#      ename       loc
# 0     KING  NEW YORK
# 1    CLARK  NEW YORK
# 2   MILLER  NEW YORK
# 3    BLAKE   CHICAGO
# 4   MARTIN   CHICAGO
# 5    ALLEN   CHICAGO
# 6   TURNER   CHICAGO
# 7    JAMES   CHICAGO
# 8     WARD   CHICAGO
# 9    JONES    DALLAS
# 10    FORD    DALLAS
# 11   SMITH    DALLAS
# 12   SCOTT    DALLAS
# 13   ADAMS    DALLAS

# %% [markdown]
# **문제 205. DALLAS에서 근무하는 사원들의 이름과 부서위치를 출력하세요**
# ```
# SQL>
# select e.ename, d.loc
#     from emp e, dept d
#     where d.loc = 'DALLAS';
# ```

# %%
emp = pd.read_csv("emp3.csv")
dept = pd.read_csv("dept3.csv")

result = pd.merge( emp, dept, on= 'deptno' )

result[['ename','loc']][result['loc']=='DALLAS']
# Out:
#     ename     loc
# 9   JONES  DALLAS
# 10   FORD  DALLAS
# 11  SMITH  DALLAS
# 12  SCOTT  DALLAS
# 13  ADAMS  DALLAS

# %% [markdown]
# **문제 206. 월급이 3000이상인 사원들의 이름과 월급과 부서위치를 출력하시오**
# ```
# SQL>
# select e.ename, e.sal, d.loc
#     from emp e, dept d
#     where e.sal >= 3000
# ```

# %%
emp = pd.read_csv("emp3.csv")
dept = pd.read_csv("dept3.csv")

result= pd.merge( emp, dept, on = 'deptno')

result[['ename', 'sal', 'loc']][result['sal'] >=3000 ]
# Out:
#     ename   sal       loc
# 0    KING  5000  NEW YORK
# 10   FORD  3000    DALLAS
# 12  SCOTT  3000    DALLAS

# %% [markdown]
# **문제 207. 부서번호가 10번, 20번인 사원들의 이름과 부서위치와 부서번호를 출력하시오**
# ```
# SQL>
# select e.ename, d.loc, d.deptno
#     from emp e, dept d
#     where d.deptno in (10, 20);
# ```

# %%
emp = pd.read_csv("emp3.csv")
dept = pd.read_csv("dept3.csv")

result = pd.merge(emp, dept, on = 'deptno')

result[['ename', 'sal','loc' ]][result['deptno'].isin ([10, 20])]
# Out:
#      ename   sal       loc
# 0     KING  5000  NEW YORK
# 1    CLARK  2450  NEW YORK
# 2   MILLER  1300  NEW YORK
# 9    JONES  2975    DALLAS
# 10    FORD  3000    DALLAS
# 11   SMITH   800    DALLAS
# 12   SCOTT  3000    DALLAS
# 13   ADAMS  1100    DALLAS

# %% [markdown]
# **문제 208. 월급이 1000 에서 3000 사이인 사원들의 이름과 월급과 부서위치를 출력하시오**
# ```
# SQL>
# select e.ename, e.sal, d.loc
#     from emp e, dept d
#     where e.sal between 1000 and 3000;
# ```

# %%
emp = pd.read_csv("emp3.csv")
dept = pd.read_csv("dept3.csv")

result = pd.merge(emp, dept, on = 'deptno')

result[['ename', 'sal', 'loc']][result['sal'].between(1000, 3000)]
# Out:
#      ename   sal       loc
# 1    CLARK  2450  NEW YORK
# 2   MILLER  1300  NEW YORK
# 3    BLAKE  2850   CHICAGO
# 4   MARTIN  1250   CHICAGO
# 5    ALLEN  1600   CHICAGO
# 6   TURNER  1500   CHICAGO
# 8     WARD  1250   CHICAGO
# 9    JONES  2975    DALLAS
# 10    FORD  3000    DALLAS
# 12   SCOTT  3000    DALLAS
# 13   ADAMS  1100    DALLAS

# %% [markdown]
# **문제 209. 아래의 SQL을 Pandas로 구현하시오**
# ```
# select e.ename, d.loc
#     from emp e, dept d
#     where e.deptno (+) = d.deptno;
# ```

# %%
emp = pd.read_csv("emp3.csv")
dept = pd.read_csv("dept3.csv")

result = pd.merge( emp, dept, on='deptno', how='right')  # outer join의 조건을 조정하기 위한 how = 'right'

result[['ename','loc']]
# Out:
#      ename       loc
# 0     KING  NEW YORK
# 1    CLARK  NEW YORK
# 2   MILLER  NEW YORK
# 3    JONES    DALLAS
# 4     FORD    DALLAS
# 5    SMITH    DALLAS
# 6    SCOTT    DALLAS
# 7    ADAMS    DALLAS
# 8    BLAKE   CHICAGO
# 9   MARTIN   CHICAGO
# 10   ALLEN   CHICAGO
# 11  TURNER   CHICAGO
# 12   JAMES   CHICAGO
# 13    WARD   CHICAGO
# 14     NaN    BOSTON

# %% [markdown]
# **문제 210. 아래의 SQL을 Pandas로 구현하시오**
# ```
# SQL>
# select e.ename, d.loc
#     from emp e full outer join dept d
#     on (e.deptno = d.deptno)
# ```

# %%
emp = pd.read_csv("emp3.csv")
dept = pd.read_csv("dept3.csv")

result = pd.merge( emp, dept, on='deptno', how='outer')  # full outer join의 조건을 조정하기 위한 how = 'outer'

result[['ename','loc']]
# Out:
#      ename       loc
# 0     KING  NEW YORK
# 1    CLARK  NEW YORK
# 2   MILLER  NEW YORK
# 3    BLAKE   CHICAGO
# 4   MARTIN   CHICAGO
# 5    ALLEN   CHICAGO
# 6   TURNER   CHICAGO
# 7    JAMES   CHICAGO
# 8     WARD   CHICAGO
# 9    JONES    DALLAS
# 10    FORD    DALLAS
# 11   SMITH    DALLAS
# 12   SCOTT    DALLAS
# 13   ADAMS    DALLAS
# 14     NaN    BOSTON

# %% [markdown]
# #66. Pandas를 이용한 서브쿼리
#
# 예: JONES보다 더 많은 월급을 받는 사원들의 이름과 월급을 출력하시오
# ```
# SQL>
# select ename, sal
#     from emp
#     where sal > ( select sal
#                     from emp
#                     where ename = 'JONES' )
# ```

# %%
emp = pd.read_csv("emp3.csv")
dept = pd.read_csv("dept3.csv")

J_sal = emp['sal'][emp['ename']=='JONES'].values[0] # JONES 월급을 J_sal 변수에 담는다
"""
Series 타입으로 서브쿼리를 할 수 없다
value의 값으로 출력이 되어야지만이 검색을 할 수 있는 조건으로 만족시킬 수 있다
"""
print(type(J_sal))   # Series 타입
emp[['ename','sal']][emp['sal'] > J_sal]
# Out:
# 2975
#     ename   sal
# 0    KING  5000
# 9    FORD  3000
# 11  SCOTT  3000

# %% [markdown]
# **문제 211. 아래의 서브쿼리를 Pandas로 구현하시오**
# ```
# SQL>
# select ename, sal
#     from emp
#     where job = ( select job
#                     from emp
#                     where ename ='SCOTT');
# ```

# %%
emp = pd.read_csv("emp3.csv")
dept = pd.read_csv("dept3.csv")

value = emp['job'][emp['ename']=='SCOTT'].values[0]

emp[['ename', 'sal']][emp['job']==value]
# Out:
#     ename   sal
# 9    FORD  3000
# 11  SCOTT  3000

# %% [markdown]
# **문제 212. 아래의 서브쿼리의 결과를 Pandas로 수행하시오**
# ```
# SQL>
# select ename, sal
#     from emp
#     where job = ( select job
#                     from emp
#                     where ename = 'SCOTT' )
#         and ename !='SCOTT';
# ```

# %%
emp = pd.read_csv("emp3.csv")

values = emp['job'][emp['ename']=='SCOTT'].values[0]

emp[['ename', 'sal']][(emp['job'] == value) & (emp['ename'] !='SCOTT')]
# Out:
#   ename   sal
# 9  FORD  3000

# %% [markdown]
# - 판다스에서 and는 &이고 or는 | 입니다.
# - &와 |를 쓸때는 괄호로 묶어줘야 합니다.
# - ~ 은  not이고 != 는 같지 않다의 연산자

# %% [markdown]
# #67. Pandas와 Oracle 그룹함수 비교
#
# ```
# SQL>
# select max(sal)
#     from emp;
# ```

# %%
print( emp['sal'].max() ) # 최대 월급
print( emp['sal'].min() ) # 최소 월급
print( emp['sal'].sum() ) # 총 월급
print( emp['sal'].var() ) # 분산값
print( emp['sal'].std() ) # 표준편차값
# Out:
# 5000
# 800
# 29025
# 1398313.8736263737
# 1182.5032235162716

# %% [markdown]
# **문제 213. 아래의 SQL을 Pandas로 구현하시오**
# ```
# SQL>
# select max(sal)
#     from emp
#     where deptno = 20;
# ```

# %%
emp['sal'][emp['deptno']==20].max()
# Out:
# 3000

# %% [markdown]
# **문제 214. 아래의 SQL을 Pandas로 구현하시오**
# ```
# SQL>
# select min(sal)
#     from emp
#     where job = 'SALESMAN';
# ```

# %%
emp['sal'][emp['job']=='SALESMAN'].min()
# Out:
# 1250

# %% [markdown]
# **문제 215. emp12.csv를 판다스 데이터 프레임으로 만들어서 출력하시오**

# %%
uploaded = files.upload()
emp12=pd.read_csv("emp122.csv")
emp12

# %% [markdown]
# **문제 216. 우리반에서 최소 나이를 출력하시오**

# %%
emp12['AGE'].min()
# Out:
# 24

# %% [markdown]
# **문제 217. 아래의 SQL을 Pandas로 구현하시오**
# ```
# SQL>
# select job, max(sal)
#     from emp
#     group by job;
# ```

# %%
result = emp.groupby('job')['sal'].max()
print(type(result)) # Series의 형태이기 때문에 데이터를 조작하기가 힘들다
result
# Out:
# <class 'pandas.core.series.Series'>
# job
# ANALYST      3000
# CLERK        1300
# MANAGER      2975
# PRESIDENT    5000
# SALESMAN     1600
# Name: sal, dtype: int64

# %%
result = emp.groupby('job')['sal'].max().reset_index()  # reset_index를 통해 컬럼을 하나를 더 추가하여 DataFrame으로 출력할 수 있게함
print(type(result))
result
# Out:
# <class 'pandas.core.frame.DataFrame'>
#          job   sal
# 0    ANALYST  3000
# 1      CLERK  1300
# 2    MANAGER  2975
# 3  PRESIDENT  5000
# 4   SALESMAN  1600

# %% [markdown]
# **문제 218. 아래의 SQL을 판다스로 구현하시오**
# ```
# SQL>
# select deptno, sum( sal )
#     from emp
#     group by deptno;
# ```

# %%
emp.groupby('deptno')['sal'].sum().reset_index()
# Out:
#    deptno    sal
# 0      10   8750
# 1      20  10875
# 2      30   9400

# %% [markdown]
# **문제 219. 아래의 SQL을 판다스로 구현하시오**
# ```
# SQL>
# select detpno, sum(sal)
#     from emp
#     where deptno != 20
#     group by deptno;
# ```

# %%
result = emp.groupby('deptno')['sal'].sum().reset_index()
result[['deptno', 'sal']][ result['deptno'] != 20 ]
# Out:
#    deptno   sal
# 0      10  8750
# 2      30  9400

# %% [markdown]
# **문제 220. 어제 마지막 문제로 만든 함수를 이용해서 아래와 같이 출력되게 하시오**
#
#
#
# ![동전확률.PNG](data:image/png;base64,...)

# %%
import random

class Coin_Prob():

    def __init__(self):
        coin = ['front', 'back']
        cnt = 0
        print('동전 던지기를 시작하겠습니다.')
        
        for e in range(1, 10000):
            a=[]
            for i in range(1, 11):
                result = random.choice(coin)
                
                if result == 'front':
                    cnt += 1
                print(f"동전을 10 번 던져서 {i}개 앞면이 나올 확률{cnt/10000}")

Coin_Prob()
# Out:
# 스트리밍 출력 내용이 길어서 마지막 5000줄이 삭제되었습니다.
# 동전을 10 번 던져서 8개 앞면이 나올 확률1.7644
# 동전을 10 번 던져서 9개 앞면이 나올 확률1.7645
# 동전을 10 번 던져서 10개 앞면이 나올 확률1.7646
# 동전을 10 번 던져서 1개 앞면이 나올 확률1.7646
# 동전을 10 번 던져서 2개 앞면이 나올 확률1.7646
# 동전을 10 번 던져서 3개 앞면이 나올 확률1.7647
# 동전을 10 번 던져서 4개 앞면이 나올 확률1.7647
# 동전을 10 번 던져서 5개 앞면이 나올 확률1.7648
# 동전을 10 번 던져서 6개 앞면이 나올 확률1.7648
# 동전을 10 번 던져서 7개 앞면이 나올 확률1.7648
# 동전을 10 번 던져서 8개 앞면이 나올 확률1.7648
# 동전을 10 번 던져서 9개 앞면이 나올 확률1.7649
# 동전을 10 번 던져서 10개 앞면이 나올 확률1.7649
# 동전을 10 번 던져서 1개 앞면이 나올 확률1.765
# 동전을 10 번 던져서 2개 앞면이 나올 확률1.765
# 동전을 10 번 던져서 3개 앞면이 나올 확률1.7651
# 동전을 10 번 던져서 4개 앞면이 나올 확률1.7651
# 동전을 10 번 던져서 5개 앞면이 나올 확률1.7651
# 동전을 10 번 던져서 6개 앞면이 나올 확률1.7651
# 동전을 10 번 던져서 7개 앞면이 나올 확률1.7651
# 동전을 10 번 던져서 8개 앞면이 나올 확률1.7652
# 동전을 10 번 던져서 9개 앞면이 나올 확률1.7652
# 동전을 10 번 던져서 10개 앞면이 나올 확률1.7652
# 동전을 10 번 던져서 1개 앞면이 나올 확률1.7653
# 동전을 10 번 던져서 2개 앞면이 나올 확률1.7654
# 동전을 10 번 던져서 3개 앞면이 나올 확률1.7655
# 동전을 10 번 던져서 4개 앞면이 나올 확률1.7655
# 동전을 10 번 던져서 5개 앞면이 나올 확률1.7656
# 동전을 10 번 던져서 6개 앞면이 나올 확률1.7656
# 동전을 10 번 던져서 7개 앞면이 나올 확률1.7657
# 동전을 10 번 던져서 8개 앞면이 나올 확률1.7657
# 동전을 10 번 던져서 9개 앞면이 나올 확률1.7657
# 동전을 10 번 던져서 10개 앞면이 나올 확률1.7658
# 동전을 10 번 던져서 1개 앞면이 나올 확률1.7659
# 동전을 10 번 던져서 2개 앞면이 나올 확률1.7659
# 동전을 10 번 던져서 3개 앞면이 나올 확률1.7659
# 동전을 10 번 던져서 4개 앞면이 나올 확률1.766
# 동전을 10 번 던져서 5개 앞면이 나올 확률1.766
# 동전을 10 번 던져서 6개 앞면이 나올 확률1.7661
# 동전을 10 번 던져서 7개 앞면이 나올 확률1.7661
# 동전을 10 번 던져서 8개 앞면이 나올 확률1.7661
# 동전을 10 번 던져서 9개 앞면이 나올 확률1.7661
# 동전을 10 번 던져서 10개 앞면이 나올 확률1.7661
# 동전을 10 번 던져서 1개 앞면이 나올 확률1.7662
# 동전을 10 번 던져서 2개 앞면이 나올 확률1.7663
# 동전을 10 번 던져서 3개 앞면이 나올 확률1.7663
# 동전을 10 번 던져서 4개 앞면이 나올 확률1.7664
# 동전을 10 번 던져서 5개 앞면이 나올 확률1.7664
# 동전을 10 번 던져서 6개 앞면이 나올 확률1.7665
# 동전을 10 번 던져서 7개 앞면이 나올 확률1.7666
# 동전을 10 번 던져서 8개 앞면이 나올 확률1.7666
# 동전을 10 번 던져서 9개 앞면이 나올 확률1.7666
# 동전을 10 번 던져서 10개 앞면이 나올 확률1.7666
# 동전을 10 번 던져서 1개 앞면이 나올 확률1.7666
# 동전을 10 번 던져서 2개 앞면이 나올 확률1.7667
# 동전을 10 번 던져서 3개 앞면이 나올 확률1.7667
# 동전을 10 번 던져서 4개 앞면이 나올 확률1.7668
# 동전을 10 번 던져서 5개 앞면이 나올 확률1.7668
# 동전을 10 번 던져서 6개 앞면이 나올 확률1.7668
# 동전을 10 번 던져서 7개 앞면이 나올 확률1.7669
# 동전을 10 번 던져서 8개 앞면이 나올 확률1.767
# 동전을 10 번 던져서 9개 앞면이 나올 확률1.7671
# 동전을 10 번 던져서 10개 앞면이 나올 확률1.7671
# 동전을 10 번 던져서 1개 앞면이 나올 확률1.7671
# 동전을 10 번 던져서 2개 앞면이 나올 확률1.7672
# 동전을 10 번 던져서 3개 앞면이 나올 확률1.7673
# 동전을 10 번 던져서 4개 앞면이 나올 확률1.7673
# 동전을 10 번 던져서 5개 앞면이 나올 확률1.7673
# 동전을 10 번 던져서 6개 앞면이 나올 확률1.7674
# 동전을 10 번 던져서 7개 앞면이 나올 확률1.7675
# 동전을 10 번 던져서 8개 앞면이 나올 확률1.7675
# 동전을 10 번 던져서 9개 앞면이 나올 확률1.7676
# 동전을 10 번 던져서 10개 앞면이 나올 확률1.7676
# 동전을 10 번 던져서 1개 앞면이 나올 확률1.7677
# 동전을 10 번 던져서 2개 앞면이 나올 확률1.7678
# 동전을 10 번 던져서 3개 앞면이 나올 확률1.7679
# 동전을 10 번 던져서 4개 앞면이 나올 확률1.7679
# 동전을 10 번 던져서 5개 앞면이 나올 확률1.7679
# 동전을 10 번 던져서 6개 앞면이 나올 확률1.7679
# 동전을 10 번 던져서 7개 앞면이 나올 확률1.7679
# 동전을 10 번 던져서 8개 앞면이 나올 확률1.768
# 동전을 10 번 던져서 9개 앞면이 나올 확률1.768
# 동전을 10 번 던져서 10개 앞면이 나올 확률1.768
# 동전을 10 번 던져서 1개 앞면이 나올 확률1.768
# 동전을 10 번 던져서 2개 앞면이 나올 확률1.7681
# 동전을 10 번 던져서 3개 앞면이 나올 확률1.7682
# 동전을 10 번 던져서 4개 앞면이 나올 확률1.7683
# 동전을 10 번 던져서 5개 앞면이 나올 확률1.7684
# 동전을 10 번 던져서 6개 앞면이 나올 확률1.7685
# 동전을 10 번 던져서 7개 앞면이 나올 확률1.7685
# 동전을 10 번 던져서 8개 앞면이 나올 확률1.7685
# 동전을 10 번 던져서 9개 앞면이 나올 확률1.7685
# 동전을 10 번 던져서 10개 앞면이 나올 확률1.7686
# 동전을 10 번 던져서 1개 앞면이 나올 확률1.7687
# 동전을 10 번 던져서 2개 앞면이 나올 확률1.7687
# 동전을 10 번 던져서 3개 앞면이 나올 확률1.7687
# 동전을 10 번 던져서 4개 앞면이 나올 확률1.7688
# 동전을 10 번 던져서 5개 앞면이 나올 확률1.7688
# 동전을 10 번 던져서 6개 앞면이 나올 확률1.7689
# 동전을 10 번 던져서 7개 앞면이 나올 확률1.769
# 동전을 10 번 던져서 8개 앞면이 나올 확률1.769
# 동전을 10 번 던져서 9개 앞면이 나올 확률1.7691
# 동전을 10 번 던져서 10개 앞면이 나올 확률1.7691
# 동전을 10 번 던져서 1개 앞면이 나올 확률1.7691
# 동전을 10 번 던져서 2개 앞면이 나올 확률1.7692
# 동전을 10 번 던져서 3개 앞면이 나올 확률1.7692
# 동전을 10 번 던져서 4개 앞면이 나올 확률1.7693
# 동전을 10 번 던져서 5개 앞면이 나올 확률1.7694
# 동전을 10 번 던져서 6개 앞면이 나올 확률1.7695
# 동전을 10 번 던져서 7개 앞면이 나올 확률1.7695
# 동전을 10 번 던져서 8개 앞면이 나올 확률1.7696
# 동전을 10 번 던져서 9개 앞면이 나올 확률1.7696
# 동전을 10 번 던져서 10개 앞면이 나올 확률1.7697
# 동전을 10 번 던져서 1개 앞면이 나올 확률1.7697
# 동전을 10 번 던져서 2개 앞면이 나올 확률1.7698
# 동전을 10 번 던져서 3개 앞면이 나올 확률1.7699
# 동전을 10 번 던져서 4개 앞면이 나올 확률1.77
# 동전을 10 번 던져서 5개 앞면이 나올 확률1.7701
# 동전을 10 번 던져서 6개 앞면이 나올 확률1.7701
# 동전을 10 번 던져서 7개 앞면이 나올 확률1.7701
# 동전을 10 번 던져서 8개 앞면이 나올 확률1.7702
# 동전을 10 번 던져서 9개 앞면이 나올 확률1.7703
# 동전을 10 번 던져서 10개 앞면이 나올 확률1.7703
# 동전을 10 번 던져서 1개 앞면이 나올 확률1.7704
# 동전을 10 번 던져서 2개 앞면이 나올 확률1.7704
# 동전을 10 번 던져서 3개 앞면이 나올 확률1.7704
# 동전을 10 번 던져서 4개 앞면이 나올 확률1.7704
# 동전을 10 번 던져서 5개 앞면이 나올 확률1.7704
# 동전을 10 번 던져서 6개 앞면이 나올 확률1.7705
# 동전을 10 번 던져서 7개 앞면이 나올 확률1.7705
# 동전을 10 번 던져서 8개 앞면이 나올 확률1.7705
# 동전을 10 번 던져서 9개 앞면이 나올 확률1.7706
# 동전을 10 번 던져서 10개 앞면이 나올 확률1.7707
# 동전을 10 번 던져서 1개 앞면이 나올 확률1.7707
# 동전을 10 번 던져서 2개 앞면이 나올 확률1.7708
# 동전을 10 번 던져서 3개 앞면이 나올 확률1.7708
# 동전을 10 번 던져서 4개 앞면이 나올 확률1.7708
# 동전을 10 번 던져서 5개 앞면이 나올 확률1.7708
# 동전을 10 번 던져서 6개 앞면이 나올 확률1.7709
# 동전을 10 번 던져서 7개 앞면이 나올 확률1.7709
# 동전을 10 번 던져서 8개 앞면이 나올 확률1.771
# 동전을 10 번 던져서 9개 앞면이 나올 확률1.771
# 동전을 10 번 던져서 10개 앞면이 나올 확률1.7711
# 동전을 10 번 던져서 1개 앞면이 나올 확률1.7712
# 동전을 10 번 던져서 2개 앞면이 나올 확률1.7713
# 동전을 10 번 던져서 3개 앞면이 나올 확률1.7714
# 동전을 10 번 던져서 4개 앞면이 나올 확률1.7714
# 동전을 10 번 던져서 5개 앞면이 나올 확률1.7715
# 동전을 10 번 던져서 6개 앞면이 나올 확률1.7716
# 동전을 10 번 던져서 7개 앞면이 나올 확률1.7716
# 동전을 10 번 던져서 8개 앞면이 나올 확률1.7717
# 동전을 10 번 던져서 9개 앞면이 나올 확률1.7718
# 동전을 10 번 던져서 10개 앞면이 나올 확률1.7718
# 동전을 10 번 던져서 1개 앞면이 나올 확률1.7718
# 동전을 10 번 던져서 2개 앞면이 나올 확률1.7718
# 동전을 10 번 던져서 3개 앞면이 나올 확률1.7718
# 동전을 10 번 던져서 4개 앞면이 나올 확률1.7719
# 동전을 10 번 던져서 5개 앞면이 나올 확률1.7719
# 동전을 10 번 던져서 6개 앞면이 나올 확률1.772
# 동전을 10 번 던져서 7개 앞면이 나올 확률1.7721
# 동전을 10 번 던져서 8개 앞면이 나올 확률1.7722
# 동전을 10 번 던져서 9개 앞면이 나올 확률1.7723
# 동전을 10 번 던져서 10개 앞면이 나올 확률1.7723
# 동전을 10 번 던져서 1개 앞면이 나올 확률1.7723
# 동전을 10 번 던져서 2개 앞면이 나올 확률1.7723
# 동전을 10 번 던져서 3개 앞면이 나올 확률1.7723
# 동전을 10 번 던져서 4개 앞면이 나올 확률1.7723
# 동전을 10 번 던져서 5개 앞면이 나올 확률1.7724
# 동전을 10 번 던져서 6개 앞면이 나올 확률1.7725
# 동전을 10 번 던져서 7개 앞면이 나올 확률1.7726
# 동전을 10 번 던져서 8개 앞면이 나올 확률1.7726
# 동전을 10 번 던져서 9개 앞면이 나올 확률1.7727
# 동전을 10 번 던져서 10개 앞면이 나올 확률1.7728
# 동전을 10 번 던져서 1개 앞면이 나올 확률1.7728
# 동전을 10 번 던져서 2개 앞면이 나올 확률1.7728
# 동전을 10 번 던져서 3개 앞면이 나올 확률1.7728
# 동전을 10 번 던져서 4개 앞면이 나올 확률1.7728
# 동전을 10 번 던져서 5개 앞면이 나올 확률1.7729
# 동전을 10 번 던져서 6개 앞면이 나올 확률1.773
# 동전을 10 번 던져서 7개 앞면이 나올 확률1.773
# 동전을 10 번 던져서 8개 앞면이 나올 확률1.773
# 동전을 10 번 던져서 9개 앞면이 나올 확률1.7731
# 동전을 10 번 던져서 10개 앞면이 나올 확률1.7731
# 동전을 10 번 던져서 1개 앞면이 나올 확률1.7732
# 동전을 10 번 던져서 2개 앞면이 나올 확률1.7733
# 동전을 10 번 던져서 3개 앞면이 나올 확률1.7734
# 동전을 10 번 던져서 4개 앞면이 나올 확률1.7734
# 동전을 10 번 던져서 5개 앞면이 나올 확률1.7735
# 동전을 10 번 던져서 6개 앞면이 나올 확률1.7735
# 동전을 10 번 던져서 7개 앞면이 나올 확률1.7735
# 동전을 10 번 던져서 8개 앞면이 나올 확률1.7735
# 동전을 10 번 던져서 9개 앞면이 나올 확률1.7736
# 동전을 10 번 던져서 10개 앞면이 나올 확률1.7737
# 동전을 10 번 던져서 1개 앞면이 나올 확률1.7738
# 동전을 10 번 던져서 2개 앞면이 나올 확률1.7739
# 동전을 10 번 던져서 3개 앞면이 나올 확률1.7739
# 동전을 10 번 던져서 4개 앞면이 나올 확률1.7739
# 동전을 10 번 던져서 5개 앞면이 나올 확률1.7739
# 동전을 10 번 던져서 6개 앞면이 나올 확률1.774
# 동전을 10 번 던져서 7개 앞면이 나올 확률1.7741
# 동전을 10 번 던져서 8개 앞면이 나올 확률1.7742
# 동전을 10 번 던져서 9개 앞면이 나올 확률1.7743
# 동전을 10 번 던져서 10개 앞면이 나올 확률1.7744
# 동전을 10 번 던져서 1개 앞면이 나올 확률1.7745
# 동전을 10 번 던져서 2개 앞면이 나올 확률1.7746
# 동전을 10 번 던져서 3개 앞면이 나올 확률1.7746
# 동전을 10 번 던져서 4개 앞면이 나올 확률1.7746
# 동전을 10 번 던져서 5개 앞면이 나올 확률1.7746
# 동전을 10 번 던져서 6개 앞면이 나올 확률1.7747
# 동전을 10 번 던져서 7개 앞면이 나올 확률1.7747
# 동전을 10 번 던져서 8개 앞면이 나올 확률1.7748
# 동전을 10 번 던져서 9개 앞면이 나올 확률1.7748
# 동전을 10 번 던져서 10개 앞면이 나올 확률1.7748
# 동전을 10 번 던져서 1개 앞면이 나올 확률1.7748
# 동전을 10 번 던져서 2개 앞면이 나올 확률1.7749
# 동전을 10 번 던져서 3개 앞면이 나올 확률1.7749
# 동전을 10 번 던져서 4개 앞면이 나올 확률1.7749
# 동전을 10 번 던져서 5개 앞면이 나올 확률1.775
# 동전을 10 번 던져서 6개 앞면이 나올 확률1.775
# 동전을 10 번 던져서 7개 앞면이 나올 확률1.775
# 동전을 10 번 던져서 8개 앞면이 나올 확률1.7751
# 동전을 10 번 던져서 9개 앞면이 나올 확률1.7752
# 동전을 10 번 던져서 10개 앞면이 나올 확률1.7753
# 동전을 10 번 던져서 1개 앞면이 나올 확률1.7754
# 동전을 10 번 던져서 2개 앞면이 나올 확률1.7754
# 동전을 10 번 던져서 3개 앞면이 나올 확률1.7755
# 동전을 10 번 던져서 4개 앞면이 나올 확률1.7756
# 동전을 10 번 던져서 5개 앞면이 나올 확률1.7757
# 동전을 10 번 던져서 6개 앞면이 나올 확률1.7757
# 동전을 10 번 던져서 7개 앞면이 나올 확률1.7757
# 동전을 10 번 던져서 8개 앞면이 나올 확률1.7758
# 동전을 10 번 던져서 9개 앞면이 나올 확률1.7758
# 동전을 10 번 던져서 10개 앞면이 나올 확률1.7758
# 동전을 10 번 던져서 1개 앞면이 나올 확률1.7759
# 동전을 10 번 던져서 2개 앞면이 나올 확률1.776
# 동전을 10 번 던져서 3개 앞면이 나올 확률1.776
# 동전을 10 번 던져서 4개 앞면이 나올 확률1.7761
# 동전을 10 번 던져서 5개 앞면이 나올 확률1.7762
# 동전을 10 번 던져서 6개 앞면이 나올 확률1.7762
# 동전을 10 번 던져서 7개 앞면이 나올 확률1.7762
# 동전을 10 번 던져서 8개 앞면이 나올 확률1.7762
# 동전을 10 번 던져서 9개 앞면이 나올 확률1.7762
# 동전을 10 번 던져서 10개 앞면이 나올 확률1.7762
# 동전을 10 번 던져서 1개 앞면이 나올 확률1.7763
# 동전을 10 번 던져서 2개 앞면이 나올 확률1.7763
# 동전을 10 번 던져서 3개 앞면이 나올 확률1.7764
# 동전을 10 번 던져서 4개 앞면이 나올 확률1.7765
# 동전을 10 번 던져서 5개 앞면이 나올 확률1.7766
# 동전을 10 번 던져서 6개 앞면이 나올 확률1.7766
# 동전을 10 번 던져서 7개 앞면이 나올 확률1.7766
# 동전을 10 번 던져서 8개 앞면이 나올 확률1.7766
# 동전을 10 번 던져서 9개 앞면이 나올 확률1.7766
# 동전을 10 번 던져서 10개 앞면이 나올 확률1.7767
# 동전을 10 번 던져서 1개 앞면이 나올 확률1.7768
# 동전을 10 번 던져서 2개 앞면이 나올 확률1.7768
# 동전을 10 번 던져서 3개 앞면이 나올 확률1.7769
# 동전을 10 번 던져서 4개 앞면이 나올 확률1.7769
# 동전을 10 번 던져서 5개 앞면이 나올 확률1.7769
# 동전을 10 번 던져서 6개 앞면이 나올 확률1.7769
# 동전을 10 번 던져서 7개 앞면이 나올 확률1.777
# 동전을 10 번 던져서 8개 앞면이 나올 확률1.777
# 동전을 10 번 던져서 9개 앞면이 나올 확률1.777
# 동전을 10 번 던져서 10개 앞면이 나올 확률1.7771
# 동전을 10 번 던져서 1개 앞면이 나올 확률1.7772
# 동전을 10 번 던져서 2개 앞면이 나올 확률1.7772
# 동전을 10 번 던져서 3개 앞면이 나올 확률1.7773
# 동전을 10 번 던져서 4개 앞면이 나올 확률1.7773
# 동전을 10 번 던져서 5개 앞면이 나올 확률1.7774
# 동전을 10 번 던져서 6개 앞면이 나올 확률1.7774
# 동전을 10 번 던져서 7개 앞면이 나올 확률1.7774
# 동전을 10 번 던져서 8개 앞면이 나올 확률1.7774
# 동전을 10 번 던져서 9개 앞면이 나올 확률1.7774
# 동전을 10 번 던져서 10개 앞면이 나올 확률1.7774
# 동전을 10 번 던져서 1개 앞면이 나올 확률1.7775
# 동전을 10 번 던져서 2개 앞면이 나올 확률1.7776
# 동전을 10 번 던져서 3개 앞면이 나올 확률1.7777
# 동전을 10 번 던져서 4개 앞면이 나올 확률1.7777
# 동전을 10 번 던져서 5개 앞면이 나올 확률1.7777
# 동전을 10 번 던져서 6개 앞면이 나올 확률1.7778
# 동전을 10 번 던져서 7개 앞면이 나올 확률1.7779
# 동전을 10 번 던져서 8개 앞면이 나올 확률1.778
# 동전을 10 번 던져서 9개 앞면이 나올 확률1.7781
# 동전을 10 번 던져서 10개 앞면이 나올 확률1.7781
# 동전을 10 번 던져서 1개 앞면이 나올 확률1.7781
# 동전을 10 번 던져서 2개 앞면이 나올 확률1.7781
# 동전을 10 번 던져서 3개 앞면이 나올 확률1.7782
# 동전을 10 번 던져서 4개 앞면이 나올 확률1.7782
# 동전을 10 번 던져서 5개 앞면이 나올 확률1.7782
# 동전을 10 번 던져서 6개 앞면이 나올 확률1.7782
# 동전을 10 번 던져서 7개 앞면이 나올 확률1.7783
# 동전을 10 번 던져서 8개 앞면이 나올 확률1.7784
# 동전을 10 번 던져서 9개 앞면이 나올 확률1.7784
# 동전을 10 번 던져서 10개 앞면이 나올 확률1.7784
# 동전을 10 번 던져서 1개 앞면이 나올 확률1.7785
# 동전을 10 번 던져서 2개 앞면이 나올 확률1.7785
# 동전을 10 번 던져서 3개 앞면이 나올 확률1.7786
# 동전을 10 번 던져서 4개 앞면이 나올 확률1.7787
# 동전을 10 번 던져서 5개 앞면이 나올 확률1.7787
# 동전을 10 번 던져서 6개 앞면이 나올 확률1.7787
# 동전을 10 번 던져서 7개 앞면이 나올 확률1.7788
# 동전을 10 번 던져서 8개 앞면이 나올 확률1.7789
# 동전을 10 번 던져서 9개 앞면이 나올 확률1.779
# 동전을 10 번 던져서 10개 앞면이 나올 확률1.779
# 동전을 10 번 던져서 1개 앞면이 나올 확률1.7791
# 동전을 10 번 던져서 2개 앞면이 나올 확률1.7792
# 동전을 10 번 던져서 3개 앞면이 나올 확률1.7792
# 동전을 10 번 던져서 4개 앞면이 나올 확률1.7793
# 동전을 10 번 던져서 5개 앞면이 나올 확률1.7793
# 동전을 10 번 던져서 6개 앞면이 나올 확률1.7794
# 동전을 10 번 던져서 7개 앞면이 나올 확률1.7794
# 동전을 10 번 던져서 8개 앞면이 나올 확률1.7795
# 동전을 10 번 던져서 9개 앞면이 나올 확률1.7796
# 동전을 10 번 던져서 10개 앞면이 나올 확률1.7797
# 동전을 10 번 던져서 1개 앞면이 나올 확률1.7797
# 동전을 10 번 던져서 2개 앞면이 나올 확률1.7798
# 동전을 10 번 던져서 3개 앞면이 나올 확률1.7799
# 동전을 10 번 던져서 4개 앞면이 나올 확률1.7799
# 동전을 10 번 던져서 5개 앞면이 나올 확률1.78
# 동전을 10 번 던져서 6개 앞면이 나올 확률1.78
# 동전을 10 번 던져서 7개 앞면이 나올 확률1.78
# 동전을 10 번 던져서 8개 앞면이 나올 확률1.78
# 동전을 10 번 던져서 9개 앞면이 나올 확률1.78
# 동전을 10 번 던져서 10개 앞면이 나올 확률1.78
# 동전을 10 번 던져서 1개 앞면이 나올 확률1.7801
# 동전을 10 번 던져서 2개 앞면이 나올 확률1.7802
# 동전을 10 번 던져서 3개 앞면이 나올 확률1.7802
# 동전을 10 번 던져서 4개 앞면이 나올 확률1.7802
# 동전을 10 번 던져서 5개 앞면이 나올 확률1.7802
# 동전을 10 번 던져서 6개 앞면이 나올 확률1.7803
# 동전을 10 번 던져서 7개 앞면이 나올 확률1.7804
# 동전을 10 번 던져서 8개 앞면이 나올 확률1.7804
# 동전을 10 번 던져서 9개 앞면이 나올 확률1.7805
# 동전을 10 번 던져서 10개 앞면이 나올 확률1.7806
# 동전을 10 번 던져서 1개 앞면이 나올 확률1.7807
# 동전을 10 번 던져서 2개 앞면이 나올 확률1.7808
# 동전을 10 번 던져서 3개 앞면이 나올 확률1.7809
# 동전을 10 번 던져서 4개 앞면이 나올 확률1.781
# 동전을 10 번 던져서 5개 앞면이 나올 확률1.781
# 동전을 10 번 던져서 6개 앞면이 나올 확률1.7811
# 동전을 10 번 던져서 7개 앞면이 나올 확률1.7812
# 동전을 10 번 던져서 8개 앞면이 나올 확률1.7812
# 동전을 10 번 던져서 9개 앞면이 나올 확률1.7812
# 동전을 10 번 던져서 10개 앞면이 나올 확률1.7812
# 동전을 10 번 던져서 1개 앞면이 나올 확률1.7812
# 동전을 10 번 던져서 2개 앞면이 나올 확률1.7812
# 동전을 10 번 던져서 3개 앞면이 나올 확률1.7813
# 동전을 10 번 던져서 4개 앞면이 나올 확률1.7813
# 동전을 10 번 던져서 5개 앞면이 나올 확률1.7814
# 동전을 10 번 던져서 6개 앞면이 나올 확률1.7815
# 동전을 10 번 던져서 7개 앞면이 나올 확률1.7815
# 동전을 10 번 던져서 8개 앞면이 나올 확률1.7816
# 동전을 10 번 던져서 9개 앞면이 나올 확률1.7817
# 동전을 10 번 던져서 10개 앞면이 나올 확률1.7817
# 동전을 10 번 던져서 1개 앞면이 나올 확률1.7817
# 동전을 10 번 던져서 2개 앞면이 나올 확률1.7818
# 동전을 10 번 던져서 3개 앞면이 나올 확률1.7819
# 동전을 10 번 던져서 4개 앞면이 나올 확률1.7819
# 동전을 10 번 던져서 5개 앞면이 나올 확률1.7819
# 동전을 10 번 던져서 6개 앞면이 나올 확률1.782
# 동전을 10 번 던져서 7개 앞면이 나올 확률1.7821
# 동전을 10 번 던져서 8개 앞면이 나올 확률1.7822
# 동전을 10 번 던져서 9개 앞면이 나올 확률1.7823
# 동전을 10 번 던져서 10개 앞면이 나올 확률1.7824
# 동전을 10 번 던져서 1개 앞면이 나올 확률1.7825
# 동전을 10 번 던져서 2개 앞면이 나올 확률1.7825
# 동전을 10 번 던져서 3개 앞면이 나올 확률1.7825
# 동전을 10 번 던져서 4개 앞면이 나올 확률1.7826
# 동전을 10 번 던져서 5개 앞면이 나올 확률1.7827
# 동전을 10 번 던져서 6개 앞면이 나올 확률1.7828
# 동전을 10 번 던져서 7개 앞면이 나올 확률1.7828
# 동전을 10 번 던져서 8개 앞면이 나올 확률1.7829
# 동전을 10 번 던져서 9개 앞면이 나올 확률1.783
# 동전을 10 번 던져서 10개 앞면이 나올 확률1.7831
# 동전을 10 번 던져서 1개 앞면이 나올 확률1.7832
# 동전을 10 번 던져서 2개 앞면이 나올 확률1.7832
# 동전을 10 번 던져서 3개 앞면이 나올 확률1.7833
# 동전을 10 번 던져서 4개 앞면이 나올 확률1.7833
# 동전을 10 번 던져서 5개 앞면이 나올 확률1.7834
# 동전을 10 번 던져서 6개 앞면이 나올 확률1.7834
# 동전을 10 번 던져서 7개 앞면이 나올 확률1.7834
# 동전을 10 번 던져서 8개 앞면이 나올 확률1.7835
# 동전을 10 번 던져서 9개 앞면이 나올 확률1.7836
# 동전을 10 번 던져서 10개 앞면이 나올 확률1.7836
# 동전을 10 번 던져서 1개 앞면이 나올 확률1.7837
# 동전을 10 번 던져서 2개 앞면이 나올 확률1.7837
# 동전을 10 번 던져서 3개 앞면이 나올 확률1.7838
# 동전을 10 번 던져서 4개 앞면이 나올 확률1.7838
# 동전을 10 번 던져서 5개 앞면이 나올 확률1.7838
# 동전을 10 번 던져서 6개 앞면이 나올 확률1.7838
# 동전을 10 번 던져서 7개 앞면이 나올 확률1.7839
# 동전을 10 번 던져서 8개 앞면이 나올 확률1.7839
# 동전을 10 번 던져서 9개 앞면이 나올 확률1.7839
# 동전을 10 번 던져서 10개 앞면이 나올 확률1.784
# 동전을 10 번 던져서 1개 앞면이 나올 확률1.784
# 동전을 10 번 던져서 2개 앞면이 나올 확률1.7841
# 동전을 10 번 던져서 3개 앞면이 나올 확률1.7841
# 동전을 10 번 던져서 4개 앞면이 나올 확률1.7841
# 동전을 10 번 던져서 5개 앞면이 나올 확률1.7841
# 동전을 10 번 던져서 6개 앞면이 나올 확률1.7842
# 동전을 10 번 던져서 7개 앞면이 나올 확률1.7843
# 동전을 10 번 던져서 8개 앞면이 나올 확률1.7843
# 동전을 10 번 던져서 9개 앞면이 나올 확률1.7843
# 동전을 10 번 던져서 10개 앞면이 나올 확률1.7843
# 동전을 10 번 던져서 1개 앞면이 나올 확률1.7844
# 동전을 10 번 던져서 2개 앞면이 나올 확률1.7845
# 동전을 10 번 던져서 3개 앞면이 나올 확률1.7846
# 동전을 10 번 던져서 4개 앞면이 나올 확률1.7847
# 동전을 10 번 던져서 5개 앞면이 나올 확률1.7848
# 동전을 10 번 던져서 6개 앞면이 나올 확률1.7849
# 동전을 10 번 던져서 7개 앞면이 나올 확률1.785
# 동전을 10 번 던져서 8개 앞면이 나올 확률1.785
# 동전을 10 번 던져서 9개 앞면이 나올 확률1.7851
# 동전을 10 번 던져서 10개 앞면이 나올 확률1.7851
# 동전을 10 번 던져서 1개 앞면이 나올 확률1.7852
# 동전을 10 번 던져서 2개 앞면이 나올 확률1.7852
# 동전을 10 번 던져서 3개 앞면이 나올 확률1.7853
# 동전을 10 번 던져서 4개 앞면이 나올 확률1.7854
# 동전을 10 번 던져서 5개 앞면이 나올 확률1.7855
# 동전을 10 번 던져서 6개 앞면이 나올 확률1.7855
# 동전을 10 번 던져서 7개 앞면이 나올 확률1.7856
# 동전을 10 번 던져서 8개 앞면이 나올 확률1.7857
# 동전을 10 번 던져서 9개 앞면이 나올 확률1.7857
# 동전을 10 번 던져서 10개 앞면이 나올 확률1.7858
# 동전을 10 번 던져서 1개 앞면이 나올 확률1.7858
# 동전을 10 번 던져서 2개 앞면이 나올 확률1.7858
# 동전을 10 번 던져서 3개 앞면이 나올 확률1.7859
# 동전을 10 번 던져서 4개 앞면이 나올 확률1.7859
# 동전을 10 번 던져서 5개 앞면이 나올 확률1.786
# 동전을 10 번 던져서 6개 앞면이 나올 확률1.7861
# 동전을 10 번 던져서 7개 앞면이 나올 확률1.7861
# 동전을 10 번 던져서 8개 앞면이 나올 확률1.7862
# 동전을 10 번 던져서 9개 앞면이 나올 확률1.7863
# 동전을 10 번 던져서 10개 앞면이 나올 확률1.7864
# 동전을 10 번 던져서 1개 앞면이 나올 확률1.7864
# 동전을 10 번 던져서 2개 앞면이 나올 확률1.7864
# 동전을 10 번 던져서 3개 앞면이 나올 확률1.7865
# 동전을 10 번 던져서 4개 앞면이 나올 확률1.7866
# 동전을 10 번 던져서 5개 앞면이 나올 확률1.7866
# 동전을 10 번 던져서 6개 앞면이 나올 확률1.7867
# 동전을 10 번 던져서 7개 앞면이 나올 확률1.7867
# 동전을 10 번 던져서 8개 앞면이 나올 확률1.7867
# 동전을 10 번 던져서 9개 앞면이 나올 확률1.7868
# 동전을 10 번 던져서 10개 앞면이 나올 확률1.7869
# 동전을 10 번 던져서 1개 앞면이 나올 확률1.7869
# 동전을 10 번 던져서 2개 앞면이 나올 확률1.787
# 동전을 10 번 던져서 3개 앞면이 나올 확률1.787
# 동전을 10 번 던져서 4개 앞면이 나올 확률1.7871
# 동전을 10 번 던져서 5개 앞면이 나올 확률1.7872
# 동전을 10 번 던져서 6개 앞면이 나올 확률1.7872
# 동전을 10 번 던져서 7개 앞면이 나올 확률1.7872
# 동전을 10 번 던져서 8개 앞면이 나올 확률1.7873
# 동전을 10 번 던져서 9개 앞면이 나올 확률1.7873
# 동전을 10 번 던져서 10개 앞면이 나올 확률1.7873
# 동전을 10 번 던져서 1개 앞면이 나올 확률1.7873
# 동전을 10 번 던져서 2개 앞면이 나올 확률1.7873
# 동전을 10 번 던져서 3개 앞면이 나올 확률1.7873
# 동전을 10 번 던져서 4개 앞면이 나올 확률1.7874
# 동전을 10 번 던져서 5개 앞면이 나올 확률1.7874
# 동전을 10 번 던져서 6개 앞면이 나올 확률1.7875
# 동전을 10 번 던져서 7개 앞면이 나올 확률1.7876
# 동전을 10 번 던져서 8개 앞면이 나올 확률1.7876
# 동전을 10 번 던져서 9개 앞면이 나올 확률1.7877
# 동전을 10 번 던져서 10개 앞면이 나올 확률1.7878
# 동전을 10 번 던져서 1개 앞면이 나올 확률1.7879
# 동전을 10 번 던져서 2개 앞면이 나올 확률1.788
# 동전을 10 번 던져서 3개 앞면이 나올 확률1.7881
# 동전을 10 번 던져서 4개 앞면이 나올 확률1.7881
# 동전을 10 번 던져서 5개 앞면이 나올 확률1.7881
# 동전을 10 번 던져서 6개 앞면이 나올 확률1.7881
# 동전을 10 번 던져서 7개 앞면이 나올 확률1.7882
# 동전을 10 번 던져서 8개 앞면이 나올 확률1.7883
# 동전을 10 번 던져서 9개 앞면이 나올 확률1.7883
# 동전을 10 번 던져서 10개 앞면이 나올 확률1.7884
# 동전을 10 번 던져서 1개 앞면이 나올 확률1.7884
# 동전을 10 번 던져서 2개 앞면이 나올 확률1.7884
# 동전을 10 번 던져서 3개 앞면이 나올 확률1.7885
# 동전을 10 번 던져서 4개 앞면이 나올 확률1.7885
# 동전을 10 번 던져서 5개 앞면이 나올 확률1.7886
# 동전을 10 번 던져서 6개 앞면이 나올 확률1.7886
# 동전을 10 번 던져서 7개 앞면이 나올 확률1.7886
# 동전을 10 번 던져서 8개 앞면이 나올 확률1.7887
# 동전을 10 번 던져서 9개 앞면이 나올 확률1.7888
# 동전을 10 번 던져서 10개 앞면이 나올 확률1.7888
# 동전을 10 번 던져서 1개 앞면이 나올 확률1.7888
# 동전을 10 번 던져서 2개 앞면이 나올 확률1.7889
# 동전을 10 번 던져서 3개 앞면이 나올 확률1.789
# 동전을 10 번 던져서 4개 앞면이 나올 확률1.7891
# 동전을 10 번 던져서 5개 앞면이 나올 확률1.7891
# 동전을 10 번 던져서 6개 앞면이 나올 확률1.7891
# 동전을 10 번 던져서 7개 앞면이 나올 확률1.7892
# 동전을 10 번 던져서 8개 앞면이 나올 확률1.7892
# 동전을 10 번 던져서 9개 앞면이 나올 확률1.7892
# 동전을 10 번 던져서 10개 앞면이 나올 확률1.7893
# 동전을 10 번 던져서 1개 앞면이 나올 확률1.7893
# 동전을 10 번 던져서 2개 앞면이 나올 확률1.7893
# 동전을 10 번 던져서 3개 앞면이 나올 확률1.7894
# 동전을 10 번 던져서 4개 앞면이 나올 확률1.7894
# 동전을 10 번 던져서 5개 앞면이 나올 확률1.7894
# 동전을 10 번 던져서 6개 앞면이 나올 확률1.7895
# 동전을 10 번 던져서 7개 앞면이 나올 확률1.7895
# 동전을 10 번 던져서 8개 앞면이 나올 확률1.7895
# 동전을 10 번 던져서 9개 앞면이 나올 확률1.7895
# 동전을 10 번 던져서 10개 앞면이 나올 확률1.7895
# 동전을 10 번 던져서 1개 앞면이 나올 확률1.7896
# 동전을 10 번 던져서 2개 앞면이 나올 확률1.7896
# 동전을 10 번 던져서 3개 앞면이 나올 확률1.7897
# 동전을 10 번 던져서 4개 앞면이 나올 확률1.7897
# 동전을 10 번 던져서 5개 앞면이 나올 확률1.7898
# 동전을 10 번 던져서 6개 앞면이 나올 확률1.7899
# 동전을 10 번 던져서 7개 앞면이 나올 확률1.79
# 동전을 10 번 던져서 8개 앞면이 나올 확률1.79
# 동전을 10 번 던져서 9개 앞면이 나올 확률1.7901
# 동전을 10 번 던져서 10개 앞면이 나올 확률1.7902
# 동전을 10 번 던져서 1개 앞면이 나올 확률1.7903
# 동전을 10 번 던져서 2개 앞면이 나올 확률1.7903
# 동전을 10 번 던져서 3개 앞면이 나올 확률1.7904
# 동전을 10 번 던져서 4개 앞면이 나올 확률1.7904
# 동전을 10 번 던져서 5개 앞면이 나올 확률1.7904
# 동전을 10 번 던져서 6개 앞면이 나올 확률1.7904
# 동전을 10 번 던져서 7개 앞면이 나올 확률1.7904
# 동전을 10 번 던져서 8개 앞면이 나올 확률1.7905
# 동전을 10 번 던져서 9개 앞면이 나올 확률1.7905
# 동전을 10 번 던져서 10개 앞면이 나올 확률1.7905
# 동전을 10 번 던져서 1개 앞면이 나올 확률1.7906
# 동전을 10 번 던져서 2개 앞면이 나올 확률1.7906
# 동전을 10 번 던져서 3개 앞면이 나올 확률1.7906
# 동전을 10 번 던져서 4개 앞면이 나올 확률1.7906
# 동전을 10 번 던져서 5개 앞면이 나올 확률1.7907
# 동전을 10 번 던져서 6개 앞면이 나올 확률1.7908
# 동전을 10 번 던져서 7개 앞면이 나올 확률1.7909
# 동전을 10 번 던져서 8개 앞면이 나올 확률1.791
# 동전을 10 번 던져서 9개 앞면이 나올 확률1.7911
# 동전을 10 번 던져서 10개 앞면이 나올 확률1.7912
# 동전을 10 번 던져서 1개 앞면이 나올 확률1.7913
# 동전을 10 번 던져서 2개 앞면이 나올 확률1.7913
# 동전을 10 번 던져서 3개 앞면이 나올 확률1.7913
# 동전을 10 번 던져서 4개 앞면이 나올 확률1.7913
# 동전을 10 번 던져서 5개 앞면이 나올 확률1.7914
# 동전을 10 번 던져서 6개 앞면이 나올 확률1.7914
# 동전을 10 번 던져서 7개 앞면이 나올 확률1.7914
# 동전을 10 번 던져서 8개 앞면이 나올 확률1.7914
# 동전을 10 번 던져서 9개 앞면이 나올 확률1.7915
# 동전을 10 번 던져서 10개 앞면이 나올 확률1.7916
# 동전을 10 번 던져서 1개 앞면이 나올 확률1.7917
# 동전을 10 번 던져서 2개 앞면이 나올 확률1.7918
# 동전을 10 번 던져서 3개 앞면이 나올 확률1.7918
# 동전을 10 번 던져서 4개 앞면이 나올 확률1.7918
# 동전을 10 번 던져서 5개 앞면이 나올 확률1.7918
# 동전을 10 번 던져서 6개 앞면이 나올 확률1.7919
# 동전을 10 번 던져서 7개 앞면이 나올 확률1.792
# 동전을 10 번 던져서 8개 앞면이 나올 확률1.792
# 동전을 10 번 던져서 9개 앞면이 나올 확률1.792
# 동전을 10 번 던져서 10개 앞면이 나올 확률1.7921
# 동전을 10 번 던져서 1개 앞면이 나올 확률1.7922
# 동전을 10 번 던져서 2개 앞면이 나올 확률1.7922
# 동전을 10 번 던져서 3개 앞면이 나올 확률1.7922
# 동전을 10 번 던져서 4개 앞면이 나올 확률1.7923
# 동전을 10 번 던져서 5개 앞면이 나올 확률1.7923
# 동전을 10 번 던져서 6개 앞면이 나올 확률1.7923
# 동전을 10 번 던져서 7개 앞면이 나올 확률1.7924
# 동전을 10 번 던져서 8개 앞면이 나올 확률1.7925
# 동전을 10 번 던져서 9개 앞면이 나올 확률1.7925
# 동전을 10 번 던져서 10개 앞면이 나올 확률1.7925
# 동전을 10 번 던져서 1개 앞면이 나올 확률1.7925
# 동전을 10 번 던져서 2개 앞면이 나올 확률1.7926
# 동전을 10 번 던져서 3개 앞면이 나올 확률1.7927
# 동전을 10 번 던져서 4개 앞면이 나올 확률1.7927
# 동전을 10 번 던져서 5개 앞면이 나올 확률1.7928
# 동전을 10 번 던져서 6개 앞면이 나올 확률1.7929
# 동전을 10 번 던져서 7개 앞면이 나올 확률1.793
# 동전을 10 번 던져서 8개 앞면이 나올 확률1.793
# 동전을 10 번 던져서 9개 앞면이 나올 확률1.793
# 동전을 10 번 던져서 10개 앞면이 나올 확률1.7931
# 동전을 10 번 던져서 1개 앞면이 나올 확률1.7932
# 동전을 10 번 던져서 2개 앞면이 나올 확률1.7932
# 동전을 10 번 던져서 3개 앞면이 나올 확률1.7932
# 동전을 10 번 던져서 4개 앞면이 나올 확률1.7933
# 동전을 10 번 던져서 5개 앞면이 나올 확률1.7933
# 동전을 10 번 던져서 6개 앞면이 나올 확률1.7933
# 동전을 10 번 던져서 7개 앞면이 나올 확률1.7934
# 동전을 10 번 던져서 8개 앞면이 나올 확률1.7934
# 동전을 10 번 던져서 9개 앞면이 나올 확률1.7934
# 동전을 10 번 던져서 10개 앞면이 나올 확률1.7934
# 동전을 10 번 던져서 1개 앞면이 나올 확률1.7934
# 동전을 10 번 던져서 2개 앞면이 나올 확률1.7935
# 동전을 10 번 던져서 3개 앞면이 나올 확률1.7935
# 동전을 10 번 던져서 4개 앞면이 나올 확률1.7935
# 동전을 10 번 던져서 5개 앞면이 나올 확률1.7935
# 동전을 10 번 던져서 6개 앞면이 나올 확률1.7936
# 동전을 10 번 던져서 7개 앞면이 나올 확률1.7937
# 동전을 10 번 던져서 8개 앞면이 나올 확률1.7937
# 동전을 10 번 던져서 9개 앞면이 나올 확률1.7937
# 동전을 10 번 던져서 10개 앞면이 나올 확률1.7937
# 동전을 10 번 던져서 1개 앞면이 나올 확률1.7938
# 동전을 10 번 던져서 2개 앞면이 나올 확률1.7939
# 동전을 10 번 던져서 3개 앞면이 나올 확률1.794
# 동전을 10 번 던져서 4개 앞면이 나올 확률1.794
# 동전을 10 번 던져서 5개 앞면이 나올 확률1.7941
# 동전을 10 번 던져서 6개 앞면이 나올 확률1.7941
# 동전을 10 번 던져서 7개 앞면이 나올 확률1.7942
# 동전을 10 번 던져서 8개 앞면이 나올 확률1.7943
# 동전을 10 번 던져서 9개 앞면이 나올 확률1.7944
# 동전을 10 번 던져서 10개 앞면이 나올 확률1.7944
# 동전을 10 번 던져서 1개 앞면이 나올 확률1.7944
# 동전을 10 번 던져서 2개 앞면이 나올 확률1.7945
# 동전을 10 번 던져서 3개 앞면이 나올 확률1.7945
# 동전을 10 번 던져서 4개 앞면이 나올 확률1.7946
# 동전을 10 번 던져서 5개 앞면이 나올 확률1.7946
# 동전을 10 번 던져서 6개 앞면이 나올 확률1.7946
# 동전을 10 번 던져서 7개 앞면이 나올 확률1.7946
# 동전을 10 번 던져서 8개 앞면이 나올 확률1.7946
# 동전을 10 번 던져서 9개 앞면이 나올 확률1.7947
# 동전을 10 번 던져서 10개 앞면이 나올 확률1.7947
# 동전을 10 번 던져서 1개 앞면이 나올 확률1.7948
# 동전을 10 번 던져서 2개 앞면이 나올 확률1.7948
# 동전을 10 번 던져서 3개 앞면이 나올 확률1.7949
# 동전을 10 번 던져서 4개 앞면이 나올 확률1.7949
# 동전을 10 번 던져서 5개 앞면이 나올 확률1.795
# 동전을 10 번 던져서 6개 앞면이 나올 확률1.7951
# 동전을 10 번 던져서 7개 앞면이 나올 확률1.7952
# 동전을 10 번 던져서 8개 앞면이 나올 확률1.7953
# 동전을 10 번 던져서 9개 앞면이 나올 확률1.7953
# 동전을 10 번 던져서 10개 앞면이 나올 확률1.7954
# 동전을 10 번 던져서 1개 앞면이 나올 확률1.7955
# 동전을 10 번 던져서 2개 앞면이 나올 확률1.7955
# 동전을 10 번 던져서 3개 앞면이 나올 확률1.7955
# 동전을 10 번 던져서 4개 앞면이 나올 확률1.7955
# 동전을 10 번 던져서 5개 앞면이 나올 확률1.7955
# 동전을 10 번 던져서 6개 앞면이 나올 확률1.7956
# 동전을 10 번 던져서 7개 앞면이 나올 확률1.7956
# 동전을 10 번 던져서 8개 앞면이 나올 확률1.7957
# 동전을 10 번 던져서 9개 앞면이 나올 확률1.7958
# 동전을 10 번 던져서 10개 앞면이 나올 확률1.7958
# 동전을 10 번 던져서 1개 앞면이 나올 확률1.7959
# 동전을 10 번 던져서 2개 앞면이 나올 확률1.7959
# 동전을 10 번 던져서 3개 앞면이 나올 확률1.796
# 동전을 10 번 던져서 4개 앞면이 나올 확률1.796
# 동전을 10 번 던져서 5개 앞면이 나올 확률1.796
# 동전을 10 번 던져서 6개 앞면이 나올 확률1.796
# 동전을 10 번 던져서 7개 앞면이 나올 확률1.7961
# 동전을 10 번 던져서 8개 앞면이 나올 확률1.7962
# 동전을 10 번 던져서 9개 앞면이 나올 확률1.7962
# 동전을 10 번 던져서 10개 앞면이 나올 확률1.7962
# 동전을 10 번 던져서 1개 앞면이 나올 확률1.7963
# 동전을 10 번 던져서 2개 앞면이 나올 확률1.7963
# 동전을 10 번 던져서 3개 앞면이 나올 확률1.7963
# 동전을 10 번 던져서 4개 앞면이 나올 확률1.7964
# 동전을 10 번 던져서 5개 앞면이 나올 확률1.7965
# 동전을 10 번 던져서 6개 앞면이 나올 확률1.7966
# 동전을 10 번 던져서 7개 앞면이 나올 확률1.7967
# 동전을 10 번 던져서 8개 앞면이 나올 확률1.7967
# 동전을 10 번 던져서 9개 앞면이 나올 확률1.7967
# 동전을 10 번 던져서 10개 앞면이 나올 확률1.7967
# 동전을 10 번 던져서 1개 앞면이 나올 확률1.7968
# 동전을 10 번 던져서 2개 앞면이 나올 확률1.7968
# 동전을 10 번 던져서 3개 앞면이 나올 확률1.7969
# 동전을 10 번 던져서 4개 앞면이 나올 확률1.7969
# 동전을 10 번 던져서 5개 앞면이 나올 확률1.797
# 동전을 10 번 던져서 6개 앞면이 나올 확률1.7971
# 동전을 10 번 던져서 7개 앞면이 나올 확률1.7971
# 동전을 10 번 던져서 8개 앞면이 나올 확률1.7972
# 동전을 10 번 던져서 9개 앞면이 나올 확률1.7973
# 동전을 10 번 던져서 10개 앞면이 나올 확률1.7973
# 동전을 10 번 던져서 1개 앞면이 나올 확률1.7974
# 동전을 10 번 던져서 2개 앞면이 나올 확률1.7974
# 동전을 10 번 던져서 3개 앞면이 나올 확률1.7974
# 동전을 10 번 던져서 4개 앞면이 나올 확률1.7975
# 동전을 10 번 던져서 5개 앞면이 나올 확률1.7975
# 동전을 10 번 던져서 6개 앞면이 나올 확률1.7976
# 동전을 10 번 던져서 7개 앞면이 나올 확률1.7976
# 동전을 10 번 던져서 8개 앞면이 나올 확률1.7977
# 동전을 10 번 던져서 9개 앞면이 나올 확률1.7977
# 동전을 10 번 던져서 10개 앞면이 나올 확률1.7978
# 동전을 10 번 던져서 1개 앞면이 나올 확률1.7979
# 동전을 10 번 던져서 2개 앞면이 나올 확률1.7979
# 동전을 10 번 던져서 3개 앞면이 나올 확률1.7979
# 동전을 10 번 던져서 4개 앞면이 나올 확률1.798
# 동전을 10 번 던져서 5개 앞면이 나올 확률1.798
# 동전을 10 번 던져서 6개 앞면이 나올 확률1.7981
# 동전을 10 번 던져서 7개 앞면이 나올 확률1.7981
# 동전을 10 번 던져서 8개 앞면이 나올 확률1.7982
# 동전을 10 번 던져서 9개 앞면이 나올 확률1.7982
# 동전을 10 번 던져서 10개 앞면이 나올 확률1.7983
# 동전을 10 번 던져서 1개 앞면이 나올 확률1.7983
# 동전을 10 번 던져서 2개 앞면이 나올 확률1.7983
# 동전을 10 번 던져서 3개 앞면이 나올 확률1.7984
# 동전을 10 번 던져서 4개 앞면이 나올 확률1.7985
# 동전을 10 번 던져서 5개 앞면이 나올 확률1.7986
# 동전을 10 번 던져서 6개 앞면이 나올 확률1.7986
# 동전을 10 번 던져서 7개 앞면이 나올 확률1.7986
# 동전을 10 번 던져서 8개 앞면이 나올 확률1.7987
# 동전을 10 번 던져서 9개 앞면이 나올 확률1.7987
# 동전을 10 번 던져서 10개 앞면이 나올 확률1.7988
# 동전을 10 번 던져서 1개 앞면이 나올 확률1.7989
# 동전을 10 번 던져서 2개 앞면이 나올 확률1.7989
# 동전을 10 번 던져서 3개 앞면이 나올 확률1.799
# 동전을 10 번 던져서 4개 앞면이 나올 확률1.7991
# 동전을 10 번 던져서 5개 앞면이 나올 확률1.7992
# 동전을 10 번 던져서 6개 앞면이 나올 확률1.7992
# 동전을 10 번 던져서 7개 앞면이 나올 확률1.7993
# 동전을 10 번 던져서 8개 앞면이 나올 확률1.7994
# 동전을 10 번 던져서 9개 앞면이 나올 확률1.7994
# 동전을 10 번 던져서 10개 앞면이 나올 확률1.7994
# 동전을 10 번 던져서 1개 앞면이 나올 확률1.7994
# 동전을 10 번 던져서 2개 앞면이 나올 확률1.7994
# 동전을 10 번 던져서 3개 앞면이 나올 확률1.7995
# 동전을 10 번 던져서 4개 앞면이 나올 확률1.7995
# 동전을 10 번 던져서 5개 앞면이 나올 확률1.7995
# 동전을 10 번 던져서 6개 앞면이 나올 확률1.7996
# 동전을 10 번 던져서 7개 앞면이 나올 확률1.7997
# 동전을 10 번 던져서 8개 앞면이 나올 확률1.7998
# 동전을 10 번 던져서 9개 앞면이 나올 확률1.7999
# 동전을 10 번 던져서 10개 앞면이 나올 확률1.7999
# 동전을 10 번 던져서 1개 앞면이 나올 확률1.7999
# 동전을 10 번 던져서 2개 앞면이 나올 확률1.7999
# 동전을 10 번 던져서 3개 앞면이 나올 확률1.7999
# 동전을 10 번 던져서 4개 앞면이 나올 확률1.8
# 동전을 10 번 던져서 5개 앞면이 나올 확률1.8
# 동전을 10 번 던져서 6개 앞면이 나올 확률1.8
# 동전을 10 번 던져서 7개 앞면이 나올 확률1.8
# 동전을 10 번 던져서 8개 앞면이 나올 확률1.8
# 동전을 10 번 던져서 9개 앞면이 나올 확률1.8001
# 동전을 10 번 던져서 10개 앞면이 나올 확률1.8001
# 동전을 10 번 던져서 1개 앞면이 나올 확률1.8002
# 동전을 10 번 던져서 2개 앞면이 나올 확률1.8002
# 동전을 10 번 던져서 3개 앞면이 나올 확률1.8003
# 동전을 10 번 던져서 4개 앞면이 나올 확률1.8003
# 동전을 10 번 던져서 5개 앞면이 나올 확률1.8004
# 동전을 10 번 던져서 6개 앞면이 나올 확률1.8004
# 동전을 10 번 던져서 7개 앞면이 나올 확률1.8005
# 동전을 10 번 던져서 8개 앞면이 나올 확률1.8005
# 동전을 10 번 던져서 9개 앞면이 나올 확률1.8005
# 동전을 10 번 던져서 10개 앞면이 나올 확률1.8006
# 동전을 10 번 던져서 1개 앞면이 나올 확률1.8007
# 동전을 10 번 던져서 2개 앞면이 나올 확률1.8008
# 동전을 10 번 던져서 3개 앞면이 나올 확률1.8009
# 동전을 10 번 던져서 4개 앞면이 나올 확률1.801
# 동전을 10 번 던져서 5개 앞면이 나올 확률1.8011
# 동전을 10 번 던져서 6개 앞면이 나올 확률1.8011
# 동전을 10 번 던져서 7개 앞면이 나올 확률1.8011
# 동전을 10 번 던져서 8개 앞면이 나올 확률1.8012
# 동전을 10 번 던져서 9개 앞면이 나올 확률1.8012
# 동전을 10 번 던져서 10개 앞면이 나올 확률1.8013
# 동전을 10 번 던져서 1개 앞면이 나올 확률1.8013
# 동전을 10 번 던져서 2개 앞면이 나올 확률1.8014
# 동전을 10 번 던져서 3개 앞면이 나올 확률1.8014
# 동전을 10 번 던져서 4개 앞면이 나올 확률1.8014
# 동전을 10 번 던져서 5개 앞면이 나올 확률1.8015
# 동전을 10 번 던져서 6개 앞면이 나올 확률1.8016
# 동전을 10 번 던져서 7개 앞면이 나올 확률1.8017
# 동전을 10 번 던져서 8개 앞면이 나올 확률1.8018
# 동전을 10 번 던져서 9개 앞면이 나올 확률1.8019
# 동전을 10 번 던져서 10개 앞면이 나올 확률1.802
# 동전을 10 번 던져서 1개 앞면이 나올 확률1.802
# 동전을 10 번 던져서 2개 앞면이 나올 확률1.802
# 동전을 10 번 던져서 3개 앞면이 나올 확률1.8021
# 동전을 10 번 던져서 4개 앞면이 나올 확률1.8022
# 동전을 10 번 던져서 5개 앞면이 나올 확률1.8023
# 동전을 10 번 던져서 6개 앞면이 나올 확률1.8023
# 동전을 10 번 던져서 7개 앞면이 나올 확률1.8024
# 동전을 10 번 던져서 8개 앞면이 나올 확률1.8024
# 동전을 10 번 던져서 9개 앞면이 나올 확률1.8024
# 동전을 10 번 던져서 10개 앞면이 나올 확률1.8024
# 동전을 10 번 던져서 1개 앞면이 나올 확률1.8025
# 동전을 10 번 던져서 2개 앞면이 나올 확률1.8026
# 동전을 10 번 던져서 3개 앞면이 나올 확률1.8026
# 동전을 10 번 던져서 4개 앞면이 나올 확률1.8027
# 동전을 10 번 던져서 5개 앞면이 나올 확률1.8027
# 동전을 10 번 던져서 6개 앞면이 나올 확률1.8028
# 동전을 10 번 던져서 7개 앞면이 나올 확률1.8029
# 동전을 10 번 던져서 8개 앞면이 나올 확률1.803
# 동전을 10 번 던져서 9개 앞면이 나올 확률1.803
# 동전을 10 번 던져서 10개 앞면이 나올 확률1.8031
# 동전을 10 번 던져서 1개 앞면이 나올 확률1.8031
# 동전을 10 번 던져서 2개 앞면이 나올 확률1.8032
# 동전을 10 번 던져서 3개 앞면이 나올 확률1.8032
# 동전을 10 번 던져서 4개 앞면이 나올 확률1.8032
# 동전을 10 번 던져서 5개 앞면이 나올 확률1.8033
# 동전을 10 번 던져서 6개 앞면이 나올 확률1.8034
# 동전을 10 번 던져서 7개 앞면이 나올 확률1.8035
# 동전을 10 번 던져서 8개 앞면이 나올 확률1.8036
# 동전을 10 번 던져서 9개 앞면이 나올 확률1.8037
# 동전을 10 번 던져서 10개 앞면이 나올 확률1.8037
# 동전을 10 번 던져서 1개 앞면이 나올 확률1.8037
# 동전을 10 번 던져서 2개 앞면이 나올 확률1.8037
# 동전을 10 번 던져서 3개 앞면이 나올 확률1.8037
# 동전을 10 번 던져서 4개 앞면이 나올 확률1.8038
# 동전을 10 번 던져서 5개 앞면이 나올 확률1.8038
# 동전을 10 번 던져서 6개 앞면이 나올 확률1.8039
# 동전을 10 번 던져서 7개 앞면이 나올 확률1.804
# 동전을 10 번 던져서 8개 앞면이 나올 확률1.8041
# 동전을 10 번 던져서 9개 앞면이 나올 확률1.8041
# 동전을 10 번 던져서 10개 앞면이 나올 확률1.8042
# 동전을 10 번 던져서 1개 앞면이 나올 확률1.8042
# 동전을 10 번 던져서 2개 앞면이 나올 확률1.8042
# 동전을 10 번 던져서 3개 앞면이 나올 확률1.8043
# 동전을 10 번 던져서 4개 앞면이 나올 확률1.8043
# 동전을 10 번 던져서 5개 앞면이 나올 확률1.8044
# 동전을 10 번 던져서 6개 앞면이 나올 확률1.8045
# 동전을 10 번 던져서 7개 앞면이 나올 확률1.8046
# 동전을 10 번 던져서 8개 앞면이 나올 확률1.8046
# 동전을 10 번 던져서 9개 앞면이 나올 확률1.8046
# 동전을 10 번 던져서 10개 앞면이 나올 확률1.8046
# 동전을 10 번 던져서 1개 앞면이 나올 확률1.8047
# 동전을 10 번 던져서 2개 앞면이 나올 확률1.8048
# 동전을 10 번 던져서 3개 앞면이 나올 확률1.8048
# 동전을 10 번 던져서 4개 앞면이 나올 확률1.8049
# 동전을 10 번 던져서 5개 앞면이 나올 확률1.8049
# 동전을 10 번 던져서 6개 앞면이 나올 확률1.8049
# 동전을 10 번 던져서 7개 앞면이 나올 확률1.805
# 동전을 10 번 던져서 8개 앞면이 나올 확률1.805
# 동전을 10 번 던져서 9개 앞면이 나올 확률1.805
# 동전을 10 번 던져서 10개 앞면이 나올 확률1.8051
# 동전을 10 번 던져서 1개 앞면이 나올 확률1.8052
# 동전을 10 번 던져서 2개 앞면이 나올 확률1.8053
# 동전을 10 번 던져서 3개 앞면이 나올 확률1.8053
# 동전을 10 번 던져서 4개 앞면이 나올 확률1.8054
# 동전을 10 번 던져서 5개 앞면이 나올 확률1.8055
# 동전을 10 번 던져서 6개 앞면이 나올 확률1.8056
# 동전을 10 번 던져서 7개 앞면이 나올 확률1.8056
# 동전을 10 번 던져서 8개 앞면이 나올 확률1.8056
# 동전을 10 번 던져서 9개 앞면이 나올 확률1.8056
# 동전을 10 번 던져서 10개 앞면이 나올 확률1.8056
# 동전을 10 번 던져서 1개 앞면이 나올 확률1.8057
# 동전을 10 번 던져서 2개 앞면이 나올 확률1.8058
# 동전을 10 번 던져서 3개 앞면이 나올 확률1.8059
# 동전을 10 번 던져서 4개 앞면이 나올 확률1.806
# 동전을 10 번 던져서 5개 앞면이 나올 확률1.806
# 동전을 10 번 던져서 6개 앞면이 나올 확률1.8061
# 동전을 10 번 던져서 7개 앞면이 나올 확률1.8061
# 동전을 10 번 던져서 8개 앞면이 나올 확률1.8061
# 동전을 10 번 던져서 9개 앞면이 나올 확률1.8062
# 동전을 10 번 던져서 10개 앞면이 나올 확률1.8062
# 동전을 10 번 던져서 1개 앞면이 나올 확률1.8063
# 동전을 10 번 던져서 2개 앞면이 나올 확률1.8063
# 동전을 10 번 던져서 3개 앞면이 나올 확률1.8064
# 동전을 10 번 던져서 4개 앞면이 나올 확률1.8064
# 동전을 10 번 던져서 5개 앞면이 나올 확률1.8064
# 동전을 10 번 던져서 6개 앞면이 나올 확률1.8065
# 동전을 10 번 던져서 7개 앞면이 나올 확률1.8066
# 동전을 10 번 던져서 8개 앞면이 나올 확률1.8066
# 동전을 10 번 던져서 9개 앞면이 나올 확률1.8066
# 동전을 10 번 던져서 10개 앞면이 나올 확률1.8067
# 동전을 10 번 던져서 1개 앞면이 나올 확률1.8067
# 동전을 10 번 던져서 2개 앞면이 나올 확률1.8068
# 동전을 10 번 던져서 3개 앞면이 나올 확률1.8069
# 동전을 10 번 던져서 4개 앞면이 나올 확률1.8069
# 동전을 10 번 던져서 5개 앞면이 나올 확률1.8069
# 동전을 10 번 던져서 6개 앞면이 나올 확률1.807
# 동전을 10 번 던져서 7개 앞면이 나올 확률1.807
# 동전을 10 번 던져서 8개 앞면이 나올 확률1.8071
# 동전을 10 번 던져서 9개 앞면이 나올 확률1.8072
# 동전을 10 번 던져서 10개 앞면이 나올 확률1.8072
# 동전을 10 번 던져서 1개 앞면이 나올 확률1.8073
# 동전을 10 번 던져서 2개 앞면이 나올 확률1.8074
# 동전을 10 번 던져서 3개 앞면이 나올 확률1.8075
# 동전을 10 번 던져서 4개 앞면이 나올 확률1.8076
# 동전을 10 번 던져서 5개 앞면이 나올 확률1.8077
# 동전을 10 번 던져서 6개 앞면이 나올 확률1.8078
# 동전을 10 번 던져서 7개 앞면이 나올 확률1.8078
# 동전을 10 번 던져서 8개 앞면이 나올 확률1.8078
# 동전을 10 번 던져서 9개 앞면이 나올 확률1.8079
# 동전을 10 번 던져서 10개 앞면이 나올 확률1.808
# 동전을 10 번 던져서 1개 앞면이 나올 확률1.8081
# 동전을 10 번 던져서 2개 앞면이 나올 확률1.8082
# 동전을 10 번 던져서 3개 앞면이 나올 확률1.8083
# 동전을 10 번 던져서 4개 앞면이 나올 확률1.8084
# 동전을 10 번 던져서 5개 앞면이 나올 확률1.8084
# 동전을 10 번 던져서 6개 앞면이 나올 확률1.8084
# 동전을 10 번 던져서 7개 앞면이 나올 확률1.8084
# 동전을 10 번 던져서 8개 앞면이 나올 확률1.8084
# 동전을 10 번 던져서 9개 앞면이 나올 확률1.8085
# 동전을 10 번 던져서 10개 앞면이 나올 확률1.8086
# 동전을 10 번 던져서 1개 앞면이 나올 확률1.8086
# 동전을 10 번 던져서 2개 앞면이 나올 확률1.8086
# 동전을 10 번 던져서 3개 앞면이 나올 확률1.8086
# 동전을 10 번 던져서 4개 앞면이 나올 확률1.8086
# 동전을 10 번 던져서 5개 앞면이 나올 확률1.8086
# 동전을 10 번 던져서 6개 앞면이 나올 확률1.8086
# 동전을 10 번 던져서 7개 앞면이 나올 확률1.8086
# 동전을 10 번 던져서 8개 앞면이 나올 확률1.8087
# 동전을 10 번 던져서 9개 앞면이 나올 확률1.8087
# 동전을 10 번 던져서 10개 앞면이 나올 확률1.8087
# 동전을 10 번 던져서 1개 앞면이 나올 확률1.8088
# 동전을 10 번 던져서 2개 앞면이 나올 확률1.8088
# 동전을 10 번 던져서 3개 앞면이 나올 확률1.8088
# 동전을 10 번 던져서 4개 앞면이 나올 확률1.8089
# 동전을 10 번 던져서 5개 앞면이 나올 확률1.8089
# 동전을 10 번 던져서 6개 앞면이 나올 확률1.809
# 동전을 10 번 던져서 7개 앞면이 나올 확률1.8091
# 동전을 10 번 던져서 8개 앞면이 나올 확률1.8092
# 동전을 10 번 던져서 9개 앞면이 나올 확률1.8093
# 동전을 10 번 던져서 10개 앞면이 나올 확률1.8094
# 동전을 10 번 던져서 1개 앞면이 나올 확률1.8095
# 동전을 10 번 던져서 2개 앞면이 나올 확률1.8096
# 동전을 10 번 던져서 3개 앞면이 나올 확률1.8097
# 동전을 10 번 던져서 4개 앞면이 나올 확률1.8097
# 동전을 10 번 던져서 5개 앞면이 나올 확률1.8097
# 동전을 10 번 던져서 6개 앞면이 나올 확률1.8097
# 동전을 10 번 던져서 7개 앞면이 나올 확률1.8097
# 동전을 10 번 던져서 8개 앞면이 나올 확률1.8097
# 동전을 10 번 던져서 9개 앞면이 나올 확률1.8098
# 동전을 10 번 던져서 10개 앞면이 나올 확률1.8099
# 동전을 10 번 던져서 1개 앞면이 나올 확률1.8099
# 동전을 10 번 던져서 2개 앞면이 나올 확률1.81
# 동전을 10 번 던져서 3개 앞면이 나올 확률1.8101
# 동전을 10 번 던져서 4개 앞면이 나올 확률1.8101
# 동전을 10 번 던져서 5개 앞면이 나올 확률1.8101
# 동전을 10 번 던져서 6개 앞면이 나올 확률1.8102
# 동전을 10 번 던져서 7개 앞면이 나올 확률1.8102
# 동전을 10 번 던져서 8개 앞면이 나올 확률1.8103
# 동전을 10 번 던져서 9개 앞면이 나올 확률1.8104
# 동전을 10 번 던져서 10개 앞면이 나올 확률1.8105
# 동전을 10 번 던져서 1개 앞면이 나올 확률1.8105
# 동전을 10 번 던져서 2개 앞면이 나올 확률1.8106
# 동전을 10 번 던져서 3개 앞면이 나올 확률1.8106
# 동전을 10 번 던져서 4개 앞면이 나올 확률1.8106
# 동전을 10 번 던져서 5개 앞면이 나올 확률1.8106
# 동전을 10 번 던져서 6개 앞면이 나올 확률1.8106
# 동전을 10 번 던져서 7개 앞면이 나올 확률1.8106
# 동전을 10 번 던져서 8개 앞면이 나올 확률1.8106
# 동전을 10 번 던져서 9개 앞면이 나올 확률1.8107
# 동전을 10 번 던져서 10개 앞면이 나올 확률1.8108
# 동전을 10 번 던져서 1개 앞면이 나올 확률1.8109
# 동전을 10 번 던져서 2개 앞면이 나올 확률1.8109
# 동전을 10 번 던져서 3개 앞면이 나올 확률1.8109
# 동전을 10 번 던져서 4개 앞면이 나올 확률1.811
# 동전을 10 번 던져서 5개 앞면이 나올 확률1.811
# 동전을 10 번 던져서 6개 앞면이 나올 확률1.8111
# 동전을 10 번 던져서 7개 앞면이 나올 확률1.8112
# 동전을 10 번 던져서 8개 앞면이 나올 확률1.8112
# 동전을 10 번 던져서 9개 앞면이 나올 확률1.8113
# 동전을 10 번 던져서 10개 앞면이 나올 확률1.8113
# 동전을 10 번 던져서 1개 앞면이 나올 확률1.8113
# 동전을 10 번 던져서 2개 앞면이 나올 확률1.8113
# 동전을 10 번 던져서 3개 앞면이 나올 확률1.8114
# 동전을 10 번 던져서 4개 앞면이 나올 확률1.8114
# 동전을 10 번 던져서 5개 앞면이 나올 확률1.8114
# 동전을 10 번 던져서 6개 앞면이 나올 확률1.8114
# 동전을 10 번 던져서 7개 앞면이 나올 확률1.8115
# 동전을 10 번 던져서 8개 앞면이 나올 확률1.8116
# 동전을 10 번 던져서 9개 앞면이 나올 확률1.8117
# 동전을 10 번 던져서 10개 앞면이 나올 확률1.8118
# 동전을 10 번 던져서 1개 앞면이 나올 확률1.8118
# 동전을 10 번 던져서 2개 앞면이 나올 확률1.8118
# 동전을 10 번 던져서 3개 앞면이 나올 확률1.8118
# 동전을 10 번 던져서 4개 앞면이 나올 확률1.8119
# 동전을 10 번 던져서 5개 앞면이 나올 확률1.8119
# 동전을 10 번 던져서 6개 앞면이 나올 확률1.812
# 동전을 10 번 던져서 7개 앞면이 나올 확률1.812
# 동전을 10 번 던져서 8개 앞면이 나올 확률1.812
# 동전을 10 번 던져서 9개 앞면이 나올 확률1.8121
# 동전을 10 번 던져서 10개 앞면이 나올 확률1.8122
# 동전을 10 번 던져서 1개 앞면이 나올 확률1.8122
# 동전을 10 번 던져서 2개 앞면이 나올 확률1.8123
# 동전을 10 번 던져서 3개 앞면이 나올 확률1.8124
# 동전을 10 번 던져서 4개 앞면이 나올 확률1.8125
# 동전을 10 번 던져서 5개 앞면이 나올 확률1.8126
# 동전을 10 번 던져서 6개 앞면이 나올 확률1.8127
# 동전을 10 번 던져서 7개 앞면이 나올 확률1.8127
# 동전을 10 번 던져서 8개 앞면이 나올 확률1.8128
# 동전을 10 번 던져서 9개 앞면이 나올 확률1.8128
# 동전을 10 번 던져서 10개 앞면이 나올 확률1.8129
# 동전을 10 번 던져서 1개 앞면이 나올 확률1.8129
# 동전을 10 번 던져서 2개 앞면이 나올 확률1.813
# 동전을 10 번 던져서 3개 앞면이 나올 확률1.8131
# 동전을 10 번 던져서 4개 앞면이 나올 확률1.8132
# 동전을 10 번 던져서 5개 앞면이 나올 확률1.8133
# 동전을 10 번 던져서 6개 앞면이 나올 확률1.8133
# 동전을 10 번 던져서 7개 앞면이 나올 확률1.8133
# 동전을 10 번 던져서 8개 앞면이 나올 확률1.8133
# 동전을 10 번 던져서 9개 앞면이 나올 확률1.8133
# 동전을 10 번 던져서 10개 앞면이 나올 확률1.8134
# 동전을 10 번 던져서 1개 앞면이 나올 확률1.8134
# 동전을 10 번 던져서 2개 앞면이 나올 확률1.8134
# 동전을 10 번 던져서 3개 앞면이 나올 확률1.8134
# 동전을 10 번 던져서 4개 앞면이 나올 확률1.8135
# 동전을 10 번 던져서 5개 앞면이 나올 확률1.8135
# 동전을 10 번 던져서 6개 앞면이 나올 확률1.8135
# 동전을 10 번 던져서 7개 앞면이 나올 확률1.8136
# 동전을 10 번 던져서 8개 앞면이 나올 확률1.8136
# 동전을 10 번 던져서 9개 앞면이 나올 확률1.8137
# 동전을 10 번 던져서 10개 앞면이 나올 확률1.8137
# 동전을 10 번 던져서 1개 앞면이 나올 확률1.8138
# 동전을 10 번 던져서 2개 앞면이 나올 확률1.8138
# 동전을 10 번 던져서 3개 앞면이 나올 확률1.8139
# 동전을 10 번 던져서 4개 앞면이 나올 확률1.8139
# 동전을 10 번 던져서 5개 앞면이 나올 확률1.8139
# 동전을 10 번 던져서 6개 앞면이 나올 확률1.8139
# 동전을 10 번 던져서 7개 앞면이 나올 확률1.814
# 동전을 10 번 던져서 8개 앞면이 나올 확률1.814
# 동전을 10 번 던져서 9개 앞면이 나올 확률1.814
# 동전을 10 번 던져서 10개 앞면이 나올 확률1.814
# 동전을 10 번 던져서 1개 앞면이 나올 확률1.814
# 동전을 10 번 던져서 2개 앞면이 나올 확률1.8141
# 동전을 10 번 던져서 3개 앞면이 나올 확률1.8142
# 동전을 10 번 던져서 4개 앞면이 나올 확률1.8143
# 동전을 10 번 던져서 5개 앞면이 나올 확률1.8143
# 동전을 10 번 던져서 6개 앞면이 나올 확률1.8144
# 동전을 10 번 던져서 7개 앞면이 나올 확률1.8145
# 동전을 10 번 던져서 8개 앞면이 나올 확률1.8146
# 동전을 10 번 던져서 9개 앞면이 나올 확률1.8146
# 동전을 10 번 던져서 10개 앞면이 나올 확률1.8147
# 동전을 10 번 던져서 1개 앞면이 나올 확률1.8147
# 동전을 10 번 던져서 2개 앞면이 나올 확률1.8147
# 동전을 10 번 던져서 3개 앞면이 나올 확률1.8147
# 동전을 10 번 던져서 4개 앞면이 나올 확률1.8148
# 동전을 10 번 던져서 5개 앞면이 나올 확률1.8149
# 동전을 10 번 던져서 6개 앞면이 나올 확률1.8149
# 동전을 10 번 던져서 7개 앞면이 나올 확률1.815
# 동전을 10 번 던져서 8개 앞면이 나올 확률1.8151
# 동전을 10 번 던져서 9개 앞면이 나올 확률1.8152
# 동전을 10 번 던져서 10개 앞면이 나올 확률1.8152
# 동전을 10 번 던져서 1개 앞면이 나올 확률1.8153
# 동전을 10 번 던져서 2개 앞면이 나올 확률1.8154
# 동전을 10 번 던져서 3개 앞면이 나올 확률1.8155
# 동전을 10 번 던져서 4개 앞면이 나올 확률1.8155
# 동전을 10 번 던져서 5개 앞면이 나올 확률1.8156
# 동전을 10 번 던져서 6개 앞면이 나올 확률1.8156
# 동전을 10 번 던져서 7개 앞면이 나올 확률1.8157
# 동전을 10 번 던져서 8개 앞면이 나올 확률1.8157
# 동전을 10 번 던져서 9개 앞면이 나올 확률1.8157
# 동전을 10 번 던져서 10개 앞면이 나올 확률1.8157
# 동전을 10 번 던져서 1개 앞면이 나올 확률1.8158
# 동전을 10 번 던져서 2개 앞면이 나올 확률1.8159
# 동전을 10 번 던져서 3개 앞면이 나올 확률1.8159
# 동전을 10 번 던져서 4개 앞면이 나올 확률1.816
# 동전을 10 번 던져서 5개 앞면이 나올 확률1.816
# 동전을 10 번 던져서 6개 앞면이 나올 확률1.816
# 동전을 10 번 던져서 7개 앞면이 나올 확률1.8161
# 동전을 10 번 던져서 8개 앞면이 나올 확률1.8161
# 동전을 10 번 던져서 9개 앞면이 나올 확률1.8162
# 동전을 10 번 던져서 10개 앞면이 나올 확률1.8162
# 동전을 10 번 던져서 1개 앞면이 나올 확률1.8163
# 동전을 10 번 던져서 2개 앞면이 나올 확률1.8164
# 동전을 10 번 던져서 3개 앞면이 나올 확률1.8164
# 동전을 10 번 던져서 4개 앞면이 나올 확률1.8165
# 동전을 10 번 던져서 5개 앞면이 나올 확률1.8165
# 동전을 10 번 던져서 6개 앞면이 나올 확률1.8165
# 동전을 10 번 던져서 7개 앞면이 나올 확률1.8165
# 동전을 10 번 던져서 8개 앞면이 나올 확률1.8166
# 동전을 10 번 던져서 9개 앞면이 나올 확률1.8167
# 동전을 10 번 던져서 10개 앞면이 나올 확률1.8168
# 동전을 10 번 던져서 1개 앞면이 나올 확률1.8168
# 동전을 10 번 던져서 2개 앞면이 나올 확률1.8168
# 동전을 10 번 던져서 3개 앞면이 나올 확률1.8168
# 동전을 10 번 던져서 4개 앞면이 나올 확률1.8169
# 동전을 10 번 던져서 5개 앞면이 나올 확률1.8169
# 동전을 10 번 던져서 6개 앞면이 나올 확률1.8169
# 동전을 10 번 던져서 7개 앞면이 나올 확률1.8169
# 동전을 10 번 던져서 8개 앞면이 나올 확률1.8169
# 동전을 10 번 던져서 9개 앞면이 나올 확률1.817
# 동전을 10 번 던져서 10개 앞면이 나올 확률1.8171
# 동전을 10 번 던져서 1개 앞면이 나올 확률1.8171
# 동전을 10 번 던져서 2개 앞면이 나올 확률1.8171
# 동전을 10 번 던져서 3개 앞면이 나올 확률1.8171
# 동전을 10 번 던져서 4개 앞면이 나올 확률1.8172
# 동전을 10 번 던져서 5개 앞면이 나올 확률1.8172
# 동전을 10 번 던져서 6개 앞면이 나올 확률1.8172
# 동전을 10 번 던져서 7개 앞면이 나올 확률1.8173
# 동전을 10 번 던져서 8개 앞면이 나올 확률1.8174
# 동전을 10 번 던져서 9개 앞면이 나올 확률1.8174
# 동전을 10 번 던져서 10개 앞면이 나올 확률1.8175
# 동전을 10 번 던져서 1개 앞면이 나올 확률1.8176
# 동전을 10 번 던져서 2개 앞면이 나올 확률1.8177
# 동전을 10 번 던져서 3개 앞면이 나올 확률1.8177
# 동전을 10 번 던져서 4개 앞면이 나올 확률1.8178
# 동전을 10 번 던져서 5개 앞면이 나올 확률1.8179
# 동전을 10 번 던져서 6개 앞면이 나올 확률1.818
# 동전을 10 번 던져서 7개 앞면이 나올 확률1.818
# 동전을 10 번 던져서 8개 앞면이 나올 확률1.818
# 동전을 10 번 던져서 9개 앞면이 나올 확률1.818
# 동전을 10 번 던져서 10개 앞면이 나올 확률1.8181
# 동전을 10 번 던져서 1개 앞면이 나올 확률1.8182
# 동전을 10 번 던져서 2개 앞면이 나올 확률1.8182
# 동전을 10 번 던져서 3개 앞면이 나올 확률1.8183
# 동전을 10 번 던져서 4개 앞면이 나올 확률1.8184
# 동전을 10 번 던져서 5개 앞면이 나올 확률1.8185
# 동전을 10 번 던져서 6개 앞면이 나올 확률1.8186
# 동전을 10 번 던져서 7개 앞면이 나올 확률1.8186
# 동전을 10 번 던져서 8개 앞면이 나올 확률1.8186
# 동전을 10 번 던져서 9개 앞면이 나올 확률1.8186
# 동전을 10 번 던져서 10개 앞면이 나올 확률1.8186
# 동전을 10 번 던져서 1개 앞면이 나올 확률1.8187
# 동전을 10 번 던져서 2개 앞면이 나올 확률1.8188
# 동전을 10 번 던져서 3개 앞면이 나올 확률1.8189
# 동전을 10 번 던져서 4개 앞면이 나올 확률1.819
# 동전을 10 번 던져서 5개 앞면이 나올 확률1.819
# 동전을 10 번 던져서 6개 앞면이 나올 확률1.8191
# 동전을 10 번 던져서 7개 앞면이 나올 확률1.8191
# 동전을 10 번 던져서 8개 앞면이 나올 확률1.8192
# 동전을 10 번 던져서 9개 앞면이 나올 확률1.8193
# 동전을 10 번 던져서 10개 앞면이 나올 확률1.8193
# 동전을 10 번 던져서 1개 앞면이 나올 확률1.8194
# 동전을 10 번 던져서 2개 앞면이 나올 확률1.8195
# 동전을 10 번 던져서 3개 앞면이 나올 확률1.8196
# 동전을 10 번 던져서 4개 앞면이 나올 확률1.8196
# 동전을 10 번 던져서 5개 앞면이 나올 확률1.8197
# 동전을 10 번 던져서 6개 앞면이 나올 확률1.8197
# 동전을 10 번 던져서 7개 앞면이 나올 확률1.8197
# 동전을 10 번 던져서 8개 앞면이 나올 확률1.8198
# 동전을 10 번 던져서 9개 앞면이 나올 확률1.8198
# 동전을 10 번 던져서 10개 앞면이 나올 확률1.8198
# 동전을 10 번 던져서 1개 앞면이 나올 확률1.8199
# 동전을 10 번 던져서 2개 앞면이 나올 확률1.8199
# 동전을 10 번 던져서 3개 앞면이 나올 확률1.8199
# 동전을 10 번 던져서 4개 앞면이 나올 확률1.82
# 동전을 10 번 던져서 5개 앞면이 나올 확률1.8201
# 동전을 10 번 던져서 6개 앞면이 나올 확률1.8201
# 동전을 10 번 던져서 7개 앞면이 나올 확률1.8202
# 동전을 10 번 던져서 8개 앞면이 나올 확률1.8203
# 동전을 10 번 던져서 9개 앞면이 나올 확률1.8203
# 동전을 10 번 던져서 10개 앞면이 나올 확률1.8203
# 동전을 10 번 던져서 1개 앞면이 나올 확률1.8204
# 동전을 10 번 던져서 2개 앞면이 나올 확률1.8205
# 동전을 10 번 던져서 3개 앞면이 나올 확률1.8206
# 동전을 10 번 던져서 4개 앞면이 나올 확률1.8207
# 동전을 10 번 던져서 5개 앞면이 나올 확률1.8208
# 동전을 10 번 던져서 6개 앞면이 나올 확률1.8209
# 동전을 10 번 던져서 7개 앞면이 나올 확률1.821
# 동전을 10 번 던져서 8개 앞면이 나올 확률1.8211
# 동전을 10 번 던져서 9개 앞면이 나올 확률1.8212
# 동전을 10 번 던져서 10개 앞면이 나올 확률1.8213
# 동전을 10 번 던져서 1개 앞면이 나올 확률1.8214
# 동전을 10 번 던져서 2개 앞면이 나올 확률1.8214
# 동전을 10 번 던져서 3개 앞면이 나올 확률1.8215
# 동전을 10 번 던져서 4개 앞면이 나올 확률1.8215
# 동전을 10 번 던져서 5개 앞면이 나올 확률1.8216
# 동전을 10 번 던져서 6개 앞면이 나올 확률1.8217
# 동전을 10 번 던져서 7개 앞면이 나올 확률1.8218
# 동전을 10 번 던져서 8개 앞면이 나올 확률1.8218
# 동전을 10 번 던져서 9개 앞면이 나올 확률1.8219
# 동전을 10 번 던져서 10개 앞면이 나올 확률1.822
# 동전을 10 번 던져서 1개 앞면이 나올 확률1.8221
# 동전을 10 번 던져서 2개 앞면이 나올 확률1.8222
# 동전을 10 번 던져서 3개 앞면이 나올 확률1.8223
# 동전을 10 번 던져서 4개 앞면이 나올 확률1.8224
# 동전을 10 번 던져서 5개 앞면이 나올 확률1.8224
# 동전을 10 번 던져서 6개 앞면이 나올 확률1.8224
# 동전을 10 번 던져서 7개 앞면이 나올 확률1.8224
# 동전을 10 번 던져서 8개 앞면이 나올 확률1.8225
# 동전을 10 번 던져서 9개 앞면이 나올 확률1.8226
# 동전을 10 번 던져서 10개 앞면이 나올 확률1.8226
# 동전을 10 번 던져서 1개 앞면이 나올 확률1.8227
# 동전을 10 번 던져서 2개 앞면이 나올 확률1.8227
# 동전을 10 번 던져서 3개 앞면이 나올 확률1.8227
# 동전을 10 번 던져서 4개 앞면이 나올 확률1.8227
# 동전을 10 번 던져서 5개 앞면이 나올 확률1.8227
# 동전을 10 번 던져서 6개 앞면이 나올 확률1.8227
# 동전을 10 번 던져서 7개 앞면이 나올 확률1.8228
# 동전을 10 번 던져서 8개 앞면이 나올 확률1.8229
# 동전을 10 번 던져서 9개 앞면이 나올 확률1.823
# 동전을 10 번 던져서 10개 앞면이 나올 확률1.823
# 동전을 10 번 던져서 1개 앞면이 나올 확률1.8231
# 동전을 10 번 던져서 2개 앞면이 나올 확률1.8231
# 동전을 10 번 던져서 3개 앞면이 나올 확률1.8231
# 동전을 10 번 던져서 4개 앞면이 나올 확률1.8232
# 동전을 10 번 던져서 5개 앞면이 나올 확률1.8233
# 동전을 10 번 던져서 6개 앞면이 나올 확률1.8234
# 동전을 10 번 던져서 7개 앞면이 나올 확률1.8234
# 동전을 10 번 던져서 8개 앞면이 나올 확률1.8234
# 동전을 10 번 던져서 9개 앞면이 나올 확률1.8234
# 동전을 10 번 던져서 10개 앞면이 나올 확률1.8235
# 동전을 10 번 던져서 1개 앞면이 나올 확률1.8235
# 동전을 10 번 던져서 2개 앞면이 나올 확률1.8235
# 동전을 10 번 던져서 3개 앞면이 나올 확률1.8235
# 동전을 10 번 던져서 4개 앞면이 나올 확률1.8235
# 동전을 10 번 던져서 5개 앞면이 나올 확률1.8235
# 동전을 10 번 던져서 6개 앞면이 나올 확률1.8236
# 동전을 10 번 던져서 7개 앞면이 나올 확률1.8236
# 동전을 10 번 던져서 8개 앞면이 나올 확률1.8237
# 동전을 10 번 던져서 9개 앞면이 나올 확률1.8238
# 동전을 10 번 던져서 10개 앞면이 나올 확률1.8239
# 동전을 10 번 던져서 1개 앞면이 나올 확률1.824
# 동전을 10 번 던져서 2개 앞면이 나올 확률1.8241
# 동전을 10 번 던져서 3개 앞면이 나올 확률1.8241
# 동전을 10 번 던져서 4개 앞면이 나올 확률1.8242
# 동전을 10 번 던져서 5개 앞면이 나올 확률1.8243
# 동전을 10 번 던져서 6개 앞면이 나올 확률1.8243
# 동전을 10 번 던져서 7개 앞면이 나올 확률1.8243
# 동전을 10 번 던져서 8개 앞면이 나올 확률1.8243
# 동전을 10 번 던져서 9개 앞면이 나올 확률1.8244
# 동전을 10 번 던져서 10개 앞면이 나올 확률1.8245
# 동전을 10 번 던져서 1개 앞면이 나올 확률1.8245
# 동전을 10 번 던져서 2개 앞면이 나올 확률1.8245
# 동전을 10 번 던져서 3개 앞면이 나올 확률1.8246
# 동전을 10 번 던져서 4개 앞면이 나올 확률1.8246
# 동전을 10 번 던져서 5개 앞면이 나올 확률1.8246
# 동전을 10 번 던져서 6개 앞면이 나올 확률1.8246
# 동전을 10 번 던져서 7개 앞면이 나올 확률1.8247
# 동전을 10 번 던져서 8개 앞면이 나올 확률1.8248
# 동전을 10 번 던져서 9개 앞면이 나올 확률1.8248
# 동전을 10 번 던져서 10개 앞면이 나올 확률1.8248
# 동전을 10 번 던져서 1개 앞면이 나올 확률1.8249
# 동전을 10 번 던져서 2개 앞면이 나올 확률1.825
# 동전을 10 번 던져서 3개 앞면이 나올 확률1.8251
# 동전을 10 번 던져서 4개 앞면이 나올 확률1.8252
# 동전을 10 번 던져서 5개 앞면이 나올 확률1.8253
# 동전을 10 번 던져서 6개 앞면이 나올 확률1.8254
# 동전을 10 번 던져서 7개 앞면이 나올 확률1.8254
# 동전을 10 번 던져서 8개 앞면이 나올 확률1.8254
# 동전을 10 번 던져서 9개 앞면이 나올 확률1.8254
# 동전을 10 번 던져서 10개 앞면이 나올 확률1.8255
# 동전을 10 번 던져서 1개 앞면이 나올 확률1.8256
# 동전을 10 번 던져서 2개 앞면이 나올 확률1.8257
# 동전을 10 번 던져서 3개 앞면이 나올 확률1.8258
# 동전을 10 번 던져서 4개 앞면이 나올 확률1.8258
# 동전을 10 번 던져서 5개 앞면이 나올 확률1.8258
# 동전을 10 번 던져서 6개 앞면이 나올 확률1.8258
# 동전을 10 번 던져서 7개 앞면이 나올 확률1.8258
# 동전을 10 번 던져서 8개 앞면이 나올 확률1.8259
# 동전을 10 번 던져서 9개 앞면이 나올 확률1.8259
# 동전을 10 번 던져서 10개 앞면이 나올 확률1.826
# 동전을 10 번 던져서 1개 앞면이 나올 확률1.8261
# 동전을 10 번 던져서 2개 앞면이 나올 확률1.8261
# 동전을 10 번 던져서 3개 앞면이 나올 확률1.8261
# 동전을 10 번 던져서 4개 앞면이 나올 확률1.8261
# 동전을 10 번 던져서 5개 앞면이 나올 확률1.8261
# 동전을 10 번 던져서 6개 앞면이 나올 확률1.8261
# 동전을 10 번 던져서 7개 앞면이 나올 확률1.8261
# 동전을 10 번 던져서 8개 앞면이 나올 확률1.8261
# 동전을 10 번 던져서 9개 앞면이 나올 확률1.8261
# 동전을 10 번 던져서 10개 앞면이 나올 확률1.8262
# 동전을 10 번 던져서 1개 앞면이 나올 확률1.8263
# 동전을 10 번 던져서 2개 앞면이 나올 확률1.8264
# 동전을 10 번 던져서 3개 앞면이 나올 확률1.8265
# 동전을 10 번 던져서 4개 앞면이 나올 확률1.8265
# 동전을 10 번 던져서 5개 앞면이 나올 확률1.8266
# 동전을 10 번 던져서 6개 앞면이 나올 확률1.8267
# 동전을 10 번 던져서 7개 앞면이 나올 확률1.8268
# 동전을 10 번 던져서 8개 앞면이 나올 확률1.8268
# 동전을 10 번 던져서 9개 앞면이 나올 확률1.8269
# 동전을 10 번 던져서 10개 앞면이 나올 확률1.8269
# 동전을 10 번 던져서 1개 앞면이 나올 확률1.827
# 동전을 10 번 던져서 2개 앞면이 나올 확률1.8271
# 동전을 10 번 던져서 3개 앞면이 나올 확률1.8272
# 동전을 10 번 던져서 4개 앞면이 나올 확률1.8273
# 동전을 10 번 던져서 5개 앞면이 나올 확률1.8273
# 동전을 10 번 던져서 6개 앞면이 나올 확률1.8274
# 동전을 10 번 던져서 7개 앞면이 나올 확률1.8275
# 동전을 10 번 던져서 8개 앞면이 나올 확률1.8275
# 동전을 10 번 던져서 9개 앞면이 나올 확률1.8276
# 동전을 10 번 던져서 10개 앞면이 나올 확률1.8276
# 동전을 10 번 던져서 1개 앞면이 나올 확률1.8276
# 동전을 10 번 던져서 2개 앞면이 나올 확률1.8276
# 동전을 10 번 던져서 3개 앞면이 나올 확률1.8277
# 동전을 10 번 던져서 4개 앞면이 나올 확률1.8277
# 동전을 10 번 던져서 5개 앞면이 나올 확률1.8278
# 동전을 10 번 던져서 6개 앞면이 나올 확률1.8279
# 동전을 10 번 던져서 7개 앞면이 나올 확률1.828
# 동전을 10 번 던져서 8개 앞면이 나올 확률1.828
# 동전을 10 번 던져서 9개 앞면이 나올 확률1.828
# 동전을 10 번 던져서 10개 앞면이 나올 확률1.828
# 동전을 10 번 던져서 1개 앞면이 나올 확률1.828
# 동전을 10 번 던져서 2개 앞면이 나올 확률1.8281
# 동전을 10 번 던져서 3개 앞면이 나올 확률1.8282
# 동전을 10 번 던져서 4개 앞면이 나올 확률1.8283
# 동전을 10 번 던져서 5개 앞면이 나올 확률1.8283
# 동전을 10 번 던져서 6개 앞면이 나올 확률1.8284
# 동전을 10 번 던져서 7개 앞면이 나올 확률1.8285
# 동전을 10 번 던져서 8개 앞면이 나올 확률1.8285
# 동전을 10 번 던져서 9개 앞면이 나올 확률1.8286
# 동전을 10 번 던져서 10개 앞면이 나올 확률1.8287
# 동전을 10 번 던져서 1개 앞면이 나올 확률1.8288
# 동전을 10 번 던져서 2개 앞면이 나올 확률1.8289
# 동전을 10 번 던져서 3개 앞면이 나올 확률1.8289
# 동전을 10 번 던져서 4개 앞면이 나올 확률1.829
# 동전을 10 번 던져서 5개 앞면이 나올 확률1.8291
# 동전을 10 번 던져서 6개 앞면이 나올 확률1.8292
# 동전을 10 번 던져서 7개 앞면이 나올 확률1.8292
# 동전을 10 번 던져서 8개 앞면이 나올 확률1.8293
# 동전을 10 번 던져서 9개 앞면이 나올 확률1.8294
# 동전을 10 번 던져서 10개 앞면이 나올 확률1.8294
# 동전을 10 번 던져서 1개 앞면이 나올 확률1.8294
# 동전을 10 번 던져서 2개 앞면이 나올 확률1.8294
# 동전을 10 번 던져서 3개 앞면이 나올 확률1.8295
# 동전을 10 번 던져서 4개 앞면이 나올 확률1.8295
# 동전을 10 번 던져서 5개 앞면이 나올 확률1.8295
# 동전을 10 번 던져서 6개 앞면이 나올 확률1.8296
# 동전을 10 번 던져서 7개 앞면이 나올 확률1.8296
# 동전을 10 번 던져서 8개 앞면이 나올 확률1.8297
# 동전을 10 번 던져서 9개 앞면이 나올 확률1.8298
# 동전을 10 번 던져서 10개 앞면이 나올 확률1.8299
# 동전을 10 번 던져서 1개 앞면이 나올 확률1.83
# 동전을 10 번 던져서 2개 앞면이 나올 확률1.8301
# 동전을 10 번 던져서 3개 앞면이 나올 확률1.8302
# 동전을 10 번 던져서 4개 앞면이 나올 확률1.8302
# 동전을 10 번 던져서 5개 앞면이 나올 확률1.8303
# 동전을 10 번 던져서 6개 앞면이 나올 확률1.8304
# 동전을 10 번 던져서 7개 앞면이 나올 확률1.8305
# 동전을 10 번 던져서 8개 앞면이 나올 확률1.8305
# 동전을 10 번 던져서 9개 앞면이 나올 확률1.8306
# 동전을 10 번 던져서 10개 앞면이 나올 확률1.8307
# 동전을 10 번 던져서 1개 앞면이 나올 확률1.8307
# 동전을 10 번 던져서 2개 앞면이 나올 확률1.8308
# 동전을 10 번 던져서 3개 앞면이 나올 확률1.8308
# 동전을 10 번 던져서 4개 앞면이 나올 확률1.8308
# 동전을 10 번 던져서 5개 앞면이 나올 확률1.8308
# 동전을 10 번 던져서 6개 앞면이 나올 확률1.8308
# 동전을 10 번 던져서 7개 앞면이 나올 확률1.8308
# 동전을 10 번 던져서 8개 앞면이 나올 확률1.8309
# 동전을 10 번 던져서 9개 앞면이 나올 확률1.8309
# 동전을 10 번 던져서 10개 앞면이 나올 확률1.8309
# 동전을 10 번 던져서 1개 앞면이 나올 확률1.831
# 동전을 10 번 던져서 2개 앞면이 나올 확률1.831
# 동전을 10 번 던져서 3개 앞면이 나올 확률1.8311
# 동전을 10 번 던져서 4개 앞면이 나올 확률1.8312
# 동전을 10 번 던져서 5개 앞면이 나올 확률1.8312
# 동전을 10 번 던져서 6개 앞면이 나올 확률1.8312
# 동전을 10 번 던져서 7개 앞면이 나올 확률1.8313
# 동전을 10 번 던져서 8개 앞면이 나올 확률1.8313
# 동전을 10 번 던져서 9개 앞면이 나올 확률1.8314
# 동전을 10 번 던져서 10개 앞면이 나올 확률1.8315
# 동전을 10 번 던져서 1개 앞면이 나올 확률1.8316
# 동전을 10 번 던져서 2개 앞면이 나올 확률1.8317
# 동전을 10 번 던져서 3개 앞면이 나올 확률1.8317
# 동전을 10 번 던져서 4개 앞면이 나올 확률1.8318
# 동전을 10 번 던져서 5개 앞면이 나올 확률1.8318
# 동전을 10 번 던져서 6개 앞면이 나올 확률1.8319
# 동전을 10 번 던져서 7개 앞면이 나올 확률1.832
# 동전을 10 번 던져서 8개 앞면이 나올 확률1.8321
# 동전을 10 번 던져서 9개 앞면이 나올 확률1.8321
# 동전을 10 번 던져서 10개 앞면이 나올 확률1.8321
# 동전을 10 번 던져서 1개 앞면이 나올 확률1.8321
# 동전을 10 번 던져서 2개 앞면이 나올 확률1.8321
# 동전을 10 번 던져서 3개 앞면이 나올 확률1.8322
# 동전을 10 번 던져서 4개 앞면이 나올 확률1.8323
# 동전을 10 번 던져서 5개 앞면이 나올 확률1.8323
# 동전을 10 번 던져서 6개 앞면이 나올 확률1.8323
# 동전을 10 번 던져서 7개 앞면이 나올 확률1.8323
# 동전을 10 번 던져서 8개 앞면이 나올 확률1.8323
# 동전을 10 번 던져서 9개 앞면이 나올 확률1.8323
# 동전을 10 번 던져서 10개 앞면이 나올 확률1.8323
# 동전을 10 번 던져서 1개 앞면이 나올 확률1.8323
# 동전을 10 번 던져서 2개 앞면이 나올 확률1.8323
# 동전을 10 번 던져서 3개 앞면이 나올 확률1.8324
# 동전을 10 번 던져서 4개 앞면이 나올 확률1.8325
# 동전을 10 번 던져서 5개 앞면이 나올 확률1.8326
# 동전을 10 번 던져서 6개 앞면이 나올 확률1.8326
# 동전을 10 번 던져서 7개 앞면이 나올 확률1.8326
# 동전을 10 번 던져서 8개 앞면이 나올 확률1.8326
# 동전을 10 번 던져서 9개 앞면이 나올 확률1.8327
# 동전을 10 번 던져서 10개 앞면이 나올 확률1.8327
# 동전을 10 번 던져서 1개 앞면이 나올 확률1.8328
# 동전을 10 번 던져서 2개 앞면이 나올 확률1.8328
# 동전을 10 번 던져서 3개 앞면이 나올 확률1.8329
# 동전을 10 번 던져서 4개 앞면이 나올 확률1.833
# 동전을 10 번 던져서 5개 앞면이 나올 확률1.833
# 동전을 10 번 던져서 6개 앞면이 나올 확률1.833
# 동전을 10 번 던져서 7개 앞면이 나올 확률1.833
# 동전을 10 번 던져서 8개 앞면이 나올 확률1.833
# 동전을 10 번 던져서 9개 앞면이 나올 확률1.8331
# 동전을 10 번 던져서 10개 앞면이 나올 확률1.8332
# 동전을 10 번 던져서 1개 앞면이 나올 확률1.8333
# 동전을 10 번 던져서 2개 앞면이 나올 확률1.8334
# 동전을 10 번 던져서 3개 앞면이 나올 확률1.8335
# 동전을 10 번 던져서 4개 앞면이 나올 확률1.8335
# 동전을 10 번 던져서 5개 앞면이 나올 확률1.8335
# 동전을 10 번 던져서 6개 앞면이 나올 확률1.8335
# 동전을 10 번 던져서 7개 앞면이 나올 확률1.8335
# 동전을 10 번 던져서 8개 앞면이 나올 확률1.8335
# 동전을 10 번 던져서 9개 앞면이 나올 확률1.8335
# 동전을 10 번 던져서 10개 앞면이 나올 확률1.8335
# 동전을 10 번 던져서 1개 앞면이 나올 확률1.8336
# 동전을 10 번 던져서 2개 앞면이 나올 확률1.8337
# 동전을 10 번 던져서 3개 앞면이 나올 확률1.8337
# 동전을 10 번 던져서 4개 앞면이 나올 확률1.8337
# 동전을 10 번 던져서 5개 앞면이 나올 확률1.8337
# 동전을 10 번 던져서 6개 앞면이 나올 확률1.8338
# 동전을 10 번 던져서 7개 앞면이 나올 확률1.8339
# 동전을 10 번 던져서 8개 앞면이 나올 확률1.834
# 동전을 10 번 던져서 9개 앞면이 나올 확률1.834
# 동전을 10 번 던져서 10개 앞면이 나올 확률1.834
# 동전을 10 번 던져서 1개 앞면이 나올 확률1.8341
# 동전을 10 번 던져서 2개 앞면이 나올 확률1.8342
# 동전을 10 번 던져서 3개 앞면이 나올 확률1.8343
# 동전을 10 번 던져서 4개 앞면이 나올 확률1.8344
# 동전을 10 번 던져서 5개 앞면이 나올 확률1.8345
# 동전을 10 번 던져서 6개 앞면이 나올 확률1.8345
# 동전을 10 번 던져서 7개 앞면이 나올 확률1.8345
# 동전을 10 번 던져서 8개 앞면이 나올 확률1.8345
# 동전을 10 번 던져서 9개 앞면이 나올 확률1.8345
# 동전을 10 번 던져서 10개 앞면이 나올 확률1.8345
# 동전을 10 번 던져서 1개 앞면이 나올 확률1.8346
# 동전을 10 번 던져서 2개 앞면이 나올 확률1.8346
# 동전을 10 번 던져서 3개 앞면이 나올 확률1.8347
# 동전을 10 번 던져서 4개 앞면이 나올 확률1.8348
# 동전을 10 번 던져서 5개 앞면이 나올 확률1.8348
# 동전을 10 번 던져서 6개 앞면이 나올 확률1.8349
# 동전을 10 번 던져서 7개 앞면이 나올 확률1.8349
# 동전을 10 번 던져서 8개 앞면이 나올 확률1.8349
# 동전을 10 번 던져서 9개 앞면이 나올 확률1.835
# 동전을 10 번 던져서 10개 앞면이 나올 확률1.8351
# 동전을 10 번 던져서 1개 앞면이 나올 확률1.8352
# 동전을 10 번 던져서 2개 앞면이 나올 확률1.8353
# 동전을 10 번 던져서 3개 앞면이 나올 확률1.8353
# 동전을 10 번 던져서 4개 앞면이 나올 확률1.8354
# 동전을 10 번 던져서 5개 앞면이 나올 확률1.8355
# 동전을 10 번 던져서 6개 앞면이 나올 확률1.8355
# 동전을 10 번 던져서 7개 앞면이 나올 확률1.8355
# 동전을 10 번 던져서 8개 앞면이 나올 확률1.8356
# 동전을 10 번 던져서 9개 앞면이 나올 확률1.8357
# 동전을 10 번 던져서 10개 앞면이 나올 확률1.8357
# 동전을 10 번 던져서 1개 앞면이 나올 확률1.8357
# 동전을 10 번 던져서 2개 앞면이 나올 확률1.8357
# 동전을 10 번 던져서 3개 앞면이 나올 확률1.8358
# 동전을 10 번 던져서 4개 앞면이 나올 확률1.8359
# 동전을 10 번 던져서 5개 앞면이 나올 확률1.836
# 동전을 10 번 던져서 6개 앞면이 나올 확률1.836
# 동전을 10 번 던져서 7개 앞면이 나올 확률1.836
# 동전을 10 번 던져서 8개 앞면이 나올 확률1.836
# 동전을 10 번 던져서 9개 앞면이 나올 확률1.8361
# 동전을 10 번 던져서 10개 앞면이 나올 확률1.8362
# 동전을 10 번 던져서 1개 앞면이 나올 확률1.8363
# 동전을 10 번 던져서 2개 앞면이 나올 확률1.8363
# 동전을 10 번 던져서 3개 앞면이 나올 확률1.8363
# 동전을 10 번 던져서 4개 앞면이 나올 확률1.8363
# 동전을 10 번 던져서 5개 앞면이 나올 확률1.8363
# 동전을 10 번 던져서 6개 앞면이 나올 확률1.8363
# 동전을 10 번 던져서 7개 앞면이 나올 확률1.8364
# 동전을 10 번 던져서 8개 앞면이 나올 확률1.8364
# 동전을 10 번 던져서 9개 앞면이 나올 확률1.8365
# 동전을 10 번 던져서 10개 앞면이 나올 확률1.8366
# 동전을 10 번 던져서 1개 앞면이 나올 확률1.8366
# 동전을 10 번 던져서 2개 앞면이 나올 확률1.8367
# 동전을 10 번 던져서 3개 앞면이 나올 확률1.8367
# 동전을 10 번 던져서 4개 앞면이 나올 확률1.8367
# 동전을 10 번 던져서 5개 앞면이 나올 확률1.8368
# 동전을 10 번 던져서 6개 앞면이 나올 확률1.8368
# 동전을 10 번 던져서 7개 앞면이 나올 확률1.8369
# 동전을 10 번 던져서 8개 앞면이 나올 확률1.837
# 동전을 10 번 던져서 9개 앞면이 나올 확률1.8371
# 동전을 10 번 던져서 10개 앞면이 나올 확률1.8372
# 동전을 10 번 던져서 1개 앞면이 나올 확률1.8372
# 동전을 10 번 던져서 2개 앞면이 나올 확률1.8372
# 동전을 10 번 던져서 3개 앞면이 나올 확률1.8372
# 동전을 10 번 던져서 4개 앞면이 나올 확률1.8373
# 동전을 10 번 던져서 5개 앞면이 나올 확률1.8373
# 동전을 10 번 던져서 6개 앞면이 나올 확률1.8373
# 동전을 10 번 던져서 7개 앞면이 나올 확률1.8373
# 동전을 10 번 던져서 8개 앞면이 나올 확률1.8374
# 동전을 10 번 던져서 9개 앞면이 나올 확률1.8374
# 동전을 10 번 던져서 10개 앞면이 나올 확률1.8375
# 동전을 10 번 던져서 1개 앞면이 나올 확률1.8375
# 동전을 10 번 던져서 2개 앞면이 나올 확률1.8376
# 동전을 10 번 던져서 3개 앞면이 나올 확률1.8376
# 동전을 10 번 던져서 4개 앞면이 나올 확률1.8377
# 동전을 10 번 던져서 5개 앞면이 나올 확률1.8378
# 동전을 10 번 던져서 6개 앞면이 나올 확률1.8378
# 동전을 10 번 던져서 7개 앞면이 나올 확률1.8379
# 동전을 10 번 던져서 8개 앞면이 나올 확률1.8379
# 동전을 10 번 던져서 9개 앞면이 나올 확률1.838
# 동전을 10 번 던져서 10개 앞면이 나올 확률1.8381
# 동전을 10 번 던져서 1개 앞면이 나올 확률1.8381
# 동전을 10 번 던져서 2개 앞면이 나올 확률1.8382
# 동전을 10 번 던져서 3개 앞면이 나올 확률1.8382
# 동전을 10 번 던져서 4개 앞면이 나올 확률1.8382
# 동전을 10 번 던져서 5개 앞면이 나올 확률1.8382
# 동전을 10 번 던져서 6개 앞면이 나올 확률1.8383
# 동전을 10 번 던져서 7개 앞면이 나올 확률1.8383
# 동전을 10 번 던져서 8개 앞면이 나올 확률1.8383
# 동전을 10 번 던져서 9개 앞면이 나올 확률1.8383
# 동전을 10 번 던져서 10개 앞면이 나올 확률1.8384
# 동전을 10 번 던져서 1개 앞면이 나올 확률1.8384
# 동전을 10 번 던져서 2개 앞면이 나올 확률1.8384
# 동전을 10 번 던져서 3개 앞면이 나올 확률1.8385
# 동전을 10 번 던져서 4개 앞면이 나올 확률1.8385
# 동전을 10 번 던져서 5개 앞면이 나올 확률1.8385
# 동전을 10 번 던져서 6개 앞면이 나올 확률1.8386
# 동전을 10 번 던져서 7개 앞면이 나올 확률1.8386
# 동전을 10 번 던져서 8개 앞면이 나올 확률1.8386
# 동전을 10 번 던져서 9개 앞면이 나올 확률1.8387
# 동전을 10 번 던져서 10개 앞면이 나올 확률1.8387
# 동전을 10 번 던져서 1개 앞면이 나올 확률1.8387
# 동전을 10 번 던져서 2개 앞면이 나올 확률1.8387
# 동전을 10 번 던져서 3개 앞면이 나올 확률1.8387
# 동전을 10 번 던져서 4개 앞면이 나올 확률1.8387
# 동전을 10 번 던져서 5개 앞면이 나올 확률1.8387
# 동전을 10 번 던져서 6개 앞면이 나올 확률1.8387
# 동전을 10 번 던져서 7개 앞면이 나올 확률1.8388
# 동전을 10 번 던져서 8개 앞면이 나올 확률1.8389
# 동전을 10 번 던져서 9개 앞면이 나올 확률1.839
# 동전을 10 번 던져서 10개 앞면이 나올 확률1.8391
# 동전을 10 번 던져서 1개 앞면이 나올 확률1.8391
# 동전을 10 번 던져서 2개 앞면이 나올 확률1.8392
# 동전을 10 번 던져서 3개 앞면이 나올 확률1.8393
# 동전을 10 번 던져서 4개 앞면이 나올 확률1.8393
# 동전을 10 번 던져서 5개 앞면이 나올 확률1.8394
# 동전을 10 번 던져서 6개 앞면이 나올 확률1.8395
# 동전을 10 번 던져서 7개 앞면이 나올 확률1.8395
# 동전을 10 번 던져서 8개 앞면이 나올 확률1.8395
# 동전을 10 번 던져서 9개 앞면이 나올 확률1.8395
# 동전을 10 번 던져서 10개 앞면이 나올 확률1.8395
# 동전을 10 번 던져서 1개 앞면이 나올 확률1.8396
# 동전을 10 번 던져서 2개 앞면이 나올 확률1.8396
# 동전을 10 번 던져서 3개 앞면이 나올 확률1.8397
# 동전을 10 번 던져서 4개 앞면이 나올 확률1.8398
# 동전을 10 번 던져서 5개 앞면이 나올 확률1.8399
# 동전을 10 번 던져서 6개 앞면이 나올 확률1.84
# ...
# 동전을 10 번 던져서 1개 앞면이 나올 확률1.9946
# 동전을 10 번 던져서 2개 앞면이 나올 확률1.9946
# 동전을 10 번 던져서 3개 앞면이 나올 확률1.9947
# 동전을 10 번 던져서 4개 앞면이 나올 확률1.9948
# 동전을 10 번 던져서 5개 앞면이 나올 확률1.9949
# 동전을 10 번 던져서 6개 앞면이 나올 확률1.9949
# 동전을 10 번 던져서 7개 앞면이 나올 확률1.995
# 동전을 10 번 던져서 8개 앞면이 나올 확률1.9951
# 동전을 10 번 던져서 9개 앞면이 나올 확률1.9951
# 동전을 10 번 던져서 10개 앞면이 나올 확률1.9952
# 동전을 10 번 던져서 1개 앞면이 나올 확률1.9953
# 동전을 10 번 던져서 2개 앞면이 나올 확률1.9953
# 동전을 10 번 던져서 3개 앞면이 나올 확률1.9954
# 동전을 10 번 던져서 4개 앞면이 나올 확률1.9955
# 동전을 10 번 던져서 5개 앞면이 나올 확률1.9956
# 동전을 10 번 던져서 6개 앞면이 나올 확률1.9957
# 동전을 10 번 던져서 7개 앞면이 나올 확률1.9958
# 동전을 10 번 던져서 8개 앞면이 나올 확률1.9958
# 동전을 10 번 던져서 9개 앞면이 나올 확률1.9959
# 동전을 10 번 던져서 10개 앞면이 나올 확률1.996
# 동전을 10 번 던져서 1개 앞면이 나올 확률1.996
# 동전을 10 번 던져서 2개 앞면이 나올 확률1.996
# 동전을 10 번 던져서 3개 앞면이 나올 확률1.9961
# 동전을 10 번 던져서 4개 앞면이 나올 확률1.9961
# 동전을 10 번 던져서 5개 앞면이 나올 확률1.9961
# 동전을 10 번 던져서 6개 앞면이 나올 확률1.9961
# 동전을 10 번 던져서 7개 앞면이 나올 확률1.9962
# 동전을 10 번 던져서 8개 앞면이 나올 확률1.9962
# 동전을 10 번 던져서 9개 앞면이 나올 확률1.9963
# 동전을 10 번 던져서 10개 앞면이 나올 확률1.9964
# 동전을 10 번 던져서 1개 앞면이 나올 확률1.9964
# 동전을 10 번 던져서 2개 앞면이 나올 확률1.9965
# 동전을 10 번 던져서 3개 앞면이 나올 확률1.9965
# 동전을 10 번 던져서 4개 앞면이 나올 확률1.9965
# 동전을 10 번 던져서 5개 앞면이 나올 확률1.9966
# 동전을 10 번 던져서 6개 앞면이 나올 확률1.9966
# 동전을 10 번 던져서 7개 앞면이 나올 확률1.9967
# 동전을 10 번 던져서 8개 앞면이 나올 확률1.9968
# 동전을 10 번 던져서 9개 앞면이 나올 확률1.9969
# 동전을 10 번 던져서 10개 앞면이 나올 확률1.997
# 동전을 10 번 던져서 1개 앞면이 나올 확률1.997
# 동전을 10 번 던져서 2개 앞면이 나올 확률1.9971
# 동전을 10 번 던져서 3개 앞면이 나올 확률1.9971
# 동전을 10 번 던져서 4개 앞면이 나올 확률1.9971
# 동전을 10 번 던져서 5개 앞면이 나올 확률1.9971
# 동전을 10 번 던져서 6개 앞면이 나올 확률1.9971
# 동전을 10 번 던져서 7개 앞면이 나올 확률1.9972
# 동전을 10 번 던져서 8개 앞면이 나올 확률1.9972
# 동전을 10 번 던져서 9개 앞면이 나올 확률1.9973
# 동전을 10 번 던져서 10개 앞면이 나올 확률1.9973
# 동전을 10 번 던져서 1개 앞면이 나올 확률1.9973
# 동전을 10 번 던져서 2개 앞면이 나올 확률1.9973
# 동전을 10 번 던져서 3개 앞면이 나올 확률1.9974
# 동전을 10 번 던져서 4개 앞면이 나올 확률1.9974
# 동전을 10 번 던져서 5개 앞면이 나올 확률1.9974
# 동전을 10 번 던져서 6개 앞면이 나올 확률1.9975
# 동전을 10 번 던져서 7개 앞면이 나올 확률1.9975
# 동전을 10 번 던져서 8개 앞면이 나올 확률1.9975
# 동전을 10 번 던져서 9개 앞면이 나올 확률1.9976
# 동전을 10 번 던져서 10개 앞면이 나올 확률1.9976
# 동전을 10 번 던져서 1개 앞면이 나올 확률1.9976
# 동전을 10 번 던져서 2개 앞면이 나올 확률1.9976
# 동전을 10 번 던져서 3개 앞면이 나올 확률1.9976
# 동전을 10 번 던져서 4개 앞면이 나올 확률1.9977
# 동전을 10 번 던져서 5개 앞면이 나올 확률1.9977
# 동전을 10 번 던져서 6개 앞면이 나올 확률1.9978
# 동전을 10 번 던져서 7개 앞면이 나올 확률1.9978
# 동전을 10 번 던져서 8개 앞면이 나올 확률1.9978
# 동전을 10 번 던져서 9개 앞면이 나올 확률1.9979
# 동전을 10 번 던져서 10개 앞면이 나올 확률1.998
# 동전을 10 번 던져서 1개 앞면이 나올 확률1.998
# 동전을 10 번 던져서 2개 앞면이 나올 확률1.9981
# 동전을 10 번 던져서 3개 앞면이 나올 확률1.9981
# 동전을 10 번 던져서 4개 앞면이 나올 확률1.9982
# 동전을 10 번 던져서 5개 앞면이 나올 확률1.9983
# 동전을 10 번 던져서 6개 앞면이 나올 확률1.9984
# 동전을 10 번 던져서 7개 앞면이 나올 확률1.9985
# 동전을 10 번 던져서 8개 앞면이 나올 확률1.9985
# 동전을 10 번 던져서 9개 앞면이 나올 확률1.9985
# 동전을 10 번 던져서 10개 앞면이 나올 확률1.9986
# 동전을 10 번 던져서 1개 앞면이 나올 확률1.9986
# 동전을 10 번 던져서 2개 앞면이 나올 확률1.9986
# 동전을 10 번 던져서 3개 앞면이 나올 확률1.9986
# 동전을 10 번 던져서 4개 앞면이 나올 확률1.9987
# 동전을 10 번 던져서 5개 앞면이 나올 확률1.9987
# 동전을 10 번 던져서 6개 앞면이 나올 확률1.9987
# 동전을 10 번 던져서 7개 앞면이 나올 확률1.9987
# 동전을 10 번 던져서 8개 앞면이 나올 확률1.9987
# 동전을 10 번 던져서 9개 앞면이 나올 확률1.9987
# 동전을 10 번 던져서 10개 앞면이 나올 확률1.9987
# 동전을 10 번 던져서 1개 앞면이 나올 확률1.9988
# 동전을 10 번 던져서 2개 앞면이 나올 확률1.9988
# 동전을 10 번 던져서 3개 앞면이 나올 확률1.9988
# 동전을 10 번 던져서 4개 앞면이 나올 확률1.9989
# 동전을 10 번 던져서 5개 앞면이 나올 확률1.999
# 동전을 10 번 던져서 6개 앞면이 나올 확률1.9991
# 동전을 10 번 던져서 7개 앞면이 나올 확률1.9992
# 동전을 10 번 던져서 8개 앞면이 나올 확률1.9993
# 동전을 10 번 던져서 9개 앞면이 나올 확률1.9993
# 동전을 10 번 던져서 10개 앞면이 나올 확률1.9994
# 동전을 10 번 던져서 1개 앞면이 나올 확률1.9995
# 동전을 10 번 던져서 2개 앞면이 나올 확률1.9995
# 동전을 10 번 던져서 3개 앞면이 나올 확률1.9996
# 동전을 10 번 던져서 4개 앞면이 나올 확률1.9997
# 동전을 10 번 던져서 5개 앞면이 나올 확률1.9998
# 동전을 10 번 던져서 6개 앞면이 나올 확률1.9999
# 동전을 10 번 던져서 7개 앞면이 나올 확률1.9999
# 동전을 10 번 던져서 8개 앞면이 나올 확률2.0
# 동전을 10 번 던져서 9개 앞면이 나올 확률2.0
# 동전을 10 번 던져서 10개 앞면이 나올 확률2.0
# 동전을 10 번 던져서 1개 앞면이 나올 확률2.0001
# 동전을 10 번 던져서 2개 앞면이 나올 확률2.0002
# 동전을 10 번 던져서 3개 앞면이 나올 확률2.0002
# 동전을 10 번 던져서 4개 앞면이 나올 확률2.0003
# 동전을 10 번 던져서 5개 앞면이 나올 확률2.0003
# 동전을 10 번 던져서 6개 앞면이 나올 확률2.0003
# 동전을 10 번 던져서 7개 앞면이 나올 확률2.0003
# 동전을 10 번 던져서 8개 앞면이 나올 확률2.0004
# 동전을 10 번 던져서 9개 앞면이 나올 확률2.0005
# 동전을 10 번 던져서 10개 앞면이 나올 확률2.0005
# 동전을 10 번 던져서 1개 앞면이 나올 확률2.0005
# 동전을 10 번 던져서 2개 앞면이 나올 확률2.0005
# 동전을 10 번 던져서 3개 앞면이 나올 확률2.0005
# 동전을 10 번 던져서 4개 앞면이 나올 확률2.0006
# 동전을 10 번 던져서 5개 앞면이 나올 확률2.0007
# 동전을 10 번 던져서 6개 앞면이 나올 확률2.0008
# 동전을 10 번 던져서 7개 앞면이 나올 확률2.0009
# 동전을 10 번 던져서 8개 앞면이 나올 확률2.0009
# 동전을 10 번 던져서 9개 앞면이 나올 확률2.0009
# 동전을 10 번 던져서 10개 앞면이 나올 확률2.0009
# 동전을 10 번 던져서 1개 앞면이 나올 확률2.0009
# 동전을 10 번 던져서 2개 앞면이 나올 확률2.001
# 동전을 10 번 던져서 3개 앞면이 나올 확률2.001
# 동전을 10 번 던져서 4개 앞면이 나올 확률2.0011
# 동전을 10 번 던져서 5개 앞면이 나올 확률2.0011
# 동전을 10 번 던져서 6개 앞면이 나올 확률2.0011
# 동전을 10 번 던져서 7개 앞면이 나올 확률2.0011
# 동전을 10 번 던져서 8개 앞면이 나올 확률2.0011
# 동전을 10 번 던져서 9개 앞면이 나올 확률2.0011
# 동전을 10 번 던져서 10개 앞면이 나올 확률2.0012
# 동전을 10 번 던져서 1개 앞면이 나올 확률2.0013
# 동전을 10 번 던져서 2개 앞면이 나올 확률2.0013
# 동전을 10 번 던져서 3개 앞면이 나올 확률2.0014
# 동전을 10 번 던져서 4개 앞면이 나올 확률2.0014
# 동전을 10 번 던져서 5개 앞면이 나올 확률2.0015
# 동전을 10 번 던져서 6개 앞면이 나올 확률2.0016
# 동전을 10 번 던져서 7개 앞면이 나올 확률2.0017
# 동전을 10 번 던져서 8개 앞면이 나올 확률2.0017
# 동전을 10 번 던져서 9개 앞면이 나올 확률2.0018
# 동전을 10 번 던져서 10개 앞면이 나올 확률2.0019
# 동전을 10 번 던져서 1개 앞면이 나올 확률2.0019
# 동전을 10 번 던져서 2개 앞면이 나올 확률2.0019
# 동전을 10 번 던져서 3개 앞면이 나올 확률2.0019
# 동전을 10 번 던져서 4개 앞면이 나올 확률2.0019
# 동전을 10 번 던져서 5개 앞면이 나올 확률2.0019
# 동전을 10 번 던져서 6개 앞면이 나올 확률2.0019
# 동전을 10 번 던져서 7개 앞면이 나올 확률2.002
# 동전을 10 번 던져서 8개 앞면이 나올 확률2.0021
# 동전을 10 번 던져서 9개 앞면이 나올 확률2.0022
# 동전을 10 번 던져서 10개 앞면이 나올 확률2.0022
# 동전을 10 번 던져서 1개 앞면이 나올 확률2.0023
# 동전을 10 번 던져서 2개 앞면이 나올 확률2.0024
# 동전을 10 번 던져서 3개 앞면이 나올 확률2.0025
# 동전을 10 번 던져서 4개 앞면이 나올 확률2.0026
# 동전을 10 번 던져서 5개 앞면이 나올 확률2.0027
# 동전을 10 번 던져서 6개 앞면이 나올 확률2.0028
# 동전을 10 번 던져서 7개 앞면이 나올 확률2.0029
# 동전을 10 번 던져서 8개 앞면이 나올 확률2.0029
# 동전을 10 번 던져서 9개 앞면이 나올 확률2.003
# 동전을 10 번 던져서 10개 앞면이 나올 확률2.0031
# 동전을 10 번 던져서 1개 앞면이 나올 확률2.0031
# 동전을 10 번 던져서 2개 앞면이 나올 확률2.0032
# 동전을 10 번 던져서 3개 앞면이 나올 확률2.0032
# 동전을 10 번 던져서 4개 앞면이 나올 확률2.0033
# 동전을 10 번 던져서 5개 앞면이 나올 확률2.0034
# 동전을 10 번 던져서 6개 앞면이 나올 확률2.0035
# 동전을 10 번 던져서 7개 앞면이 나올 확률2.0035
# 동전을 10 번 던져서 8개 앞면이 나올 확률2.0035
# 동전을 10 번 던져서 9개 앞면이 나올 확률2.0035
# 동전을 10 번 던져서 10개 앞면이 나올 확률2.0036
# 동전을 10 번 던져서 1개 앞면이 나올 확률2.0037
# 동전을 10 번 던져서 2개 앞면이 나올 확률2.0038
# 동전을 10 번 던져서 3개 앞면이 나올 확률2.0039
# 동전을 10 번 던져서 4개 앞면이 나올 확률2.0039
# 동전을 10 번 던져서 5개 앞면이 나올 확률2.004
# 동전을 10 번 던져서 6개 앞면이 나올 확률2.004
# 동전을 10 번 던져서 7개 앞면이 나올 확률2.004
# 동전을 10 번 던져서 8개 앞면이 나올 확률2.004
# 동전을 10 번 던져서 9개 앞면이 나올 확률2.004
# 동전을 10 번 던져서 10개 앞면이 나올 확률2.0041
# 동전을 10 번 던져서 1개 앞면이 나올 확률2.0041
# 동전을 10 번 던져서 2개 앞면이 나올 확률2.0041
# 동전을 10 번 던져서 3개 앞면이 나올 확률2.0042
# 동전을 10 번 던져서 4개 앞면이 나올 확률2.0043
# 동전을 10 번 던져서 5개 앞면이 나올 확률2.0043
# 동전을 10 번 던져서 6개 앞면이 나올 확률2.0044
# 동전을 10 번 던져서 7개 앞면이 나올 확률2.0045
# 동전을 10 번 던져서 8개 앞면이 나올 확률2.0046
# 동전을 10 번 던져서 9개 앞면이 나올 확률2.0046
# 동전을 10 번 던져서 10개 앞면이 나올 확률2.0046
# 동전을 10 번 던져서 1개 앞면이 나올 확률2.0046
# 동전을 10 번 던져서 2개 앞면이 나올 확률2.0047
# 동전을 10 번 던져서 3개 앞면이 나올 확률2.0048
# 동전을 10 번 던져서 4개 앞면이 나올 확률2.0049
# 동전을 10 번 던져서 5개 앞면이 나올 확률2.0049
# 동전을 10 번 던져서 6개 앞면이 나올 확률2.005
# 동전을 10 번 던져서 7개 앞면이 나올 확률2.005
# 동전을 10 번 던져서 8개 앞면이 나올 확률2.0051
# 동전을 10 번 던져서 9개 앞면이 나올 확률2.0052
# 동전을 10 번 던져서 10개 앞면이 나올 확률2.0053
# 동전을 10 번 던져서 1개 앞면이 나올 확률2.0054
# 동전을 10 번 던져서 2개 앞면이 나올 확률2.0055
# 동전을 10 번 던져서 3개 앞면이 나올 확률2.0056
# 동전을 10 번 던져서 4개 앞면이 나올 확률2.0057
# 동전을 10 번 던져서 5개 앞면이 나올 확률2.0057
# 동전을 10 번 던져서 6개 앞면이 나올 확률2.0057
# 동전을 10 번 던져서 7개 앞면이 나올 확률2.0058
# 동전을 10 번 던져서 8개 앞면이 나올 확률2.0058
# 동전을 10 번 던져서 9개 앞면이 나올 확률2.0058
# 동전을 10 번 던져서 10개 앞면이 나올 확률2.0058
# 동전을 10 번 던져서 1개 앞면이 나올 확률2.0059
# 동전을 10 번 던져서 2개 앞면이 나올 확률2.0059
# 동전을 10 번 던져서 3개 앞면이 나올 확률2.006
# 동전을 10 번 던져서 4개 앞면이 나올 확률2.006
# 동전을 10 번 던져서 5개 앞면이 나올 확률2.006
# 동전을 10 번 던져서 6개 앞면이 나올 확률2.0061
# 동전을 10 번 던져서 7개 앞면이 나올 확률2.0061
# 동전을 10 번 던져서 8개 앞면이 나올 확률2.0061
# 동전을 10 번 던져서 9개 앞면이 나올 확률2.0062
# 동전을 10 번 던져서 10개 앞면이 나올 확률2.0062
# 동전을 10 번 던져서 1개 앞면이 나올 확률2.0063
# 동전을 10 번 던져서 2개 앞면이 나올 확률2.0064
# 동전을 10 번 던져서 3개 앞면이 나올 확률2.0064
# 동전을 10 번 던져서 4개 앞면이 나올 확률2.0064
# 동전을 10 번 던져서 5개 앞면이 나올 확률2.0064
# 동전을 10 번 던져서 6개 앞면이 나올 확률2.0064
# 동전을 10 번 던져서 7개 앞면이 나올 확률2.0065
# 동전을 10 번 던져서 8개 앞면이 나올 확률2.0065
# 동전을 10 번 던져서 9개 앞면이 나올 확률2.0066
# 동전을 10 번 던져서 10개 앞면이 나올 확률2.0067
# 동전을 10 번 던져서 1개 앞면이 나올 확률2.0068
# 동전을 10 번 던져서 2개 앞면이 나올 확률2.0069
# 동전을 10 번 던져서 3개 앞면이 나올 확률2.007
# 동전을 10 번 던져서 4개 앞면이 나올 확률2.0071
# 동전을 10 번 던져서 5개 앞면이 나올 확률2.0072
# 동전을 10 번 던져서 6개 앞면이 나올 확률2.0073
# 동전을 10 번 던져서 7개 앞면이 나올 확률2.0074
# 동전을 10 번 던져서 8개 앞면이 나올 확률2.0075
# 동전을 10 번 던져서 9개 앞면이 나올 확률2.0075
# 동전을 10 번 던져서 10개 앞면이 나올 확률2.0076
# 동전을 10 번 던져서 1개 앞면이 나올 확률2.0076
# 동전을 10 번 던져서 2개 앞면이 나올 확률2.0076
# 동전을 10 번 던져서 3개 앞면이 나올 확률2.0076
# 동전을 10 번 던져서 4개 앞면이 나올 확률2.0077
# 동전을 10 번 던져서 5개 앞면이 나올 확률2.0077
# 동전을 10 번 던져서 6개 앞면이 나올 확률2.0078
# 동전을 10 번 던져서 7개 앞면이 나올 확률2.0079
# 동전을 10 번 던져서 8개 앞면이 나올 확률2.0079
# 동전을 10 번 던져서 9개 앞면이 나올 확률2.008
# 동전을 10 번 던져서 10개 앞면이 나올 확률2.008
# 동전을 10 번 던져서 1개 앞면이 나올 확률2.0081
# 동전을 10 번 던져서 2개 앞면이 나올 확률2.0082
# 동전을 10 번 던져서 3개 앞면이 나올 확률2.0083
# 동전을 10 번 던져서 4개 앞면이 나올 확률2.0083
# 동전을 10 번 던져서 5개 앞면이 나올 확률2.0084
# 동전을 10 번 던져서 6개 앞면이 나올 확률2.0084
# 동전을 10 번 던져서 7개 앞면이 나올 확률2.0084
# 동전을 10 번 던져서 8개 앞면이 나올 확률2.0085
# 동전을 10 번 던져서 9개 앞면이 나올 확률2.0085
# 동전을 10 번 던져서 10개 앞면이 나올 확률2.0086
# 동전을 10 번 던져서 1개 앞면이 나올 확률2.0086
# 동전을 10 번 던져서 2개 앞면이 나올 확률2.0087
# 동전을 10 번 던져서 3개 앞면이 나올 확률2.0087
# 동전을 10 번 던져서 4개 앞면이 나올 확률2.0088
# 동전을 10 번 던져서 5개 앞면이 나올 확률2.0089
# 동전을 10 번 던져서 6개 앞면이 나올 확률2.009
# 동전을 10 번 던져서 7개 앞면이 나올 확률2.0091
# 동전을 10 번 던져서 8개 앞면이 나올 확률2.0091
# 동전을 10 번 던져서 9개 앞면이 나올 확률2.0091
# 동전을 10 번 던져서 10개 앞면이 나올 확률2.0092
# 동전을 10 번 던져서 1개 앞면이 나올 확률2.0093
# 동전을 10 번 던져서 2개 앞면이 나올 확률2.0093
# 동전을 10 번 던져서 3개 앞면이 나올 확률2.0093
# 동전을 10 번 던져서 4개 앞면이 나올 확률2.0093
# 동전을 10 번 던져서 5개 앞면이 나올 확률2.0093
# 동전을 10 번 던져서 6개 앞면이 나올 확률2.0094
# 동전을 10 번 던져서 7개 앞면이 나올 확률2.0095
# 동전을 10 번 던져서 8개 앞면이 나올 확률2.0096
# 동전을 10 번 던져서 9개 앞면이 나올 확률2.0097
# 동전을 10 번 던져서 10개 앞면이 나올 확률2.0098
# 동전을 10 번 던져서 1개 앞면이 나올 확률2.0098
# 동전을 10 번 던져서 2개 앞면이 나올 확률2.0098
# 동전을 10 번 던져서 3개 앞면이 나올 확률2.0098
# 동전을 10 번 던져서 4개 앞면이 나올 확률2.0099
# 동전을 10 번 던져서 5개 앞면이 나올 확률2.0099
# 동전을 10 번 던져서 6개 앞면이 나올 확률2.0099
# 동전을 10 번 던져서 7개 앞면이 나올 확률2.01
# 동전을 10 번 던져서 8개 앞면이 나올 확률2.01
# 동전을 10 번 던져서 9개 앞면이 나올 확률2.0101
# 동전을 10 번 던져서 10개 앞면이 나올 확률2.0102
# 동전을 10 번 던져서 1개 앞면이 나올 확률2.0103
# 동전을 10 번 던져서 2개 앞면이 나올 확률2.0103
# 동전을 10 번 던져서 3개 앞면이 나올 확률2.0103
# 동전을 10 번 던져서 4개 앞면이 나올 확률2.0104
# 동전을 10 번 던져서 5개 앞면이 나올 확률2.0104
# 동전을 10 번 던져서 6개 앞면이 나올 확률2.0105
# 동전을 10 번 던져서 7개 앞면이 나올 확률2.0106
# 동전을 10 번 던져서 8개 앞면이 나올 확률2.0107
# 동전을 10 번 던져서 9개 앞면이 나올 확률2.0107
# 동전을 10 번 던져서 10개 앞면이 나올 확률2.0107
# 동전을 10 번 던져서 1개 앞면이 나올 확률2.0108
# 동전을 10 번 던져서 2개 앞면이 나올 확률2.0109
# 동전을 10 번 던져서 3개 앞면이 나올 확률2.011
# 동전을 10 번 던져서 4개 앞면이 나올 확률2.0111
# 동전을 10 번 던져서 5개 앞면이 나올 확률2.0111
# 동전을 10 번 던져서 6개 앞면이 나올 확률2.0111
# 동전을 10 번 던져서 7개 앞면이 나올 확률2.0111
# 동전을 10 번 던져서 8개 앞면이 나올 확률2.0111
# 동전을 10 번 던져서 9개 앞면이 나올 확률2.0111
# 동전을 10 번 던져서 10개 앞면이 나올 확률2.0111
# 동전을 10 번 던져서 1개 앞면이 나올 확률2.0112
# 동전을 10 번 던져서 2개 앞면이 나올 확률2.0113
# 동전을 10 번 던져서 3개 앞면이 나올 확률2.0113
# 동전을 10 번 던져서 4개 앞면이 나올 확률2.0113
# 동전을 10 번 던져서 5개 앞면이 나올 확률2.0114
# 동전을 10 번 던져서 6개 앞면이 나올 확률2.0115
# 동전을 10 번 던져서 7개 앞면이 나올 확률2.0116
# 동전을 10 번 던져서 8개 앞면이 나올 확률2.0117
# 동전을 10 번 던져서 9개 앞면이 나올 확률2.0117
# 동전을 10 번 던져서 10개 앞면이 나올 확률2.0118
# 동전을 10 번 던져서 1개 앞면이 나올 확률2.0119
# 동전을 10 번 던져서 2개 앞면이 나올 확률2.0119
# 동전을 10 번 던져서 3개 앞면이 나올 확률2.0119
# 동전을 10 번 던져서 4개 앞면이 나올 확률2.012
# 동전을 10 번 던져서 5개 앞면이 나올 확률2.012
# 동전을 10 번 던져서 6개 앞면이 나올 확률2.012
# 동전을 10 번 던져서 7개 앞면이 나올 확률2.0121
# 동전을 10 번 던져서 8개 앞면이 나올 확률2.0121
# 동전을 10 번 던져서 9개 앞면이 나올 확률2.0121
# 동전을 10 번 던져서 10개 앞면이 나올 확률2.0122
# 동전을 10 번 던져서 1개 앞면이 나올 확률2.0123
# 동전을 10 번 던져서 2개 앞면이 나올 확률2.0123
# 동전을 10 번 던져서 3개 앞면이 나올 확률2.0124
# 동전을 10 번 던져서 4개 앞면이 나올 확률2.0124
# 동전을 10 번 던져서 5개 앞면이 나올 확률2.0125
# 동전을 10 번 던져서 6개 앞면이 나올 확률2.0125
# 동전을 10 번 던져서 7개 앞면이 나올 확률2.0126
# 동전을 10 번 던져서 8개 앞면이 나올 확률2.0127
# 동전을 10 번 던져서 9개 앞면이 나올 확률2.0128
# 동전을 10 번 던져서 10개 앞면이 나올 확률2.0128
# 동전을 10 번 던져서 1개 앞면이 나올 확률2.0129
# 동전을 10 번 던져서 2개 앞면이 나올 확률2.013
# 동전을 10 번 던져서 3개 앞면이 나올 확률2.0131
# 동전을 10 번 던져서 4개 앞면이 나올 확률2.0131
# 동전을 10 번 던져서 5개 앞면이 나올 확률2.0132
# 동전을 10 번 던져서 6개 앞면이 나올 확률2.0133
# 동전을 10 번 던져서 7개 앞면이 나올 확률2.0133
# 동전을 10 번 던져서 8개 앞면이 나올 확률2.0133
# 동전을 10 번 던져서 9개 앞면이 나올 확률2.0133
# 동전을 10 번 던져서 10개 앞면이 나올 확률2.0134
# 동전을 10 번 던져서 1개 앞면이 나올 확률2.0134
# 동전을 10 번 던져서 2개 앞면이 나올 확률2.0135
# 동전을 10 번 던져서 3개 앞면이 나올 확률2.0136
# 동전을 10 번 던져서 4개 앞면이 나올 확률2.0136
# 동전을 10 번 던져서 5개 앞면이 나올 확률2.0137
# 동전을 10 번 던져서 6개 앞면이 나올 확률2.0137
# 동전을 10 번 던져서 7개 앞면이 나올 확률2.0137
# 동전을 10 번 던져서 8개 앞면이 나올 확률2.0138
# 동전을 10 번 던져서 9개 앞면이 나올 확률2.0138
# 동전을 10 번 던져서 10개 앞면이 나올 확률2.0139
# 동전을 10 번 던져서 1개 앞면이 나올 확률2.0139
# 동전을 10 번 던져서 2개 앞면이 나올 확률2.0139
# 동전을 10 번 던져서 3개 앞면이 나올 확률2.014
# 동전을 10 번 던져서 4개 앞면이 나올 확률2.014
# 동전을 10 번 던져서 5개 앞면이 나올 확률2.014
# 동전을 10 번 던져서 6개 앞면이 나올 확률2.014
# 동전을 10 번 던져서 7개 앞면이 나올 확률2.0141
# 동전을 10 번 던져서 8개 앞면이 나올 확률2.0141
# 동전을 10 번 던져서 9개 앞면이 나올 확률2.0142
# 동전을 10 번 던져서 10개 앞면이 나올 확률2.0142
# 동전을 10 번 던져서 1개 앞면이 나올 확률2.0142
# 동전을 10 번 던져서 2개 앞면이 나올 확률2.0142
# 동전을 10 번 던져서 3개 앞면이 나올 확률2.0142
# 동전을 10 번 던져서 4개 앞면이 나올 확률2.0143
# 동전을 10 번 던져서 5개 앞면이 나올 확률2.0144
# 동전을 10 번 던져서 6개 앞면이 나올 확률2.0144
# 동전을 10 번 던져서 7개 앞면이 나올 확률2.0144
# 동전을 10 번 던져서 8개 앞면이 나올 확률2.0144
# 동전을 10 번 던져서 9개 앞면이 나올 확률2.0145
# 동전을 10 번 던져서 10개 앞면이 나올 확률2.0145
# 동전을 10 번 던져서 1개 앞면이 나올 확률2.0145
# 동전을 10 번 던져서 2개 앞면이 나올 확률2.0145
# 동전을 10 번 던져서 3개 앞면이 나올 확률2.0146
# 동전을 10 번 던져서 4개 앞면이 나올 확률2.0146
# 동전을 10 번 던져서 5개 앞면이 나올 확률2.0147
# 동전을 10 번 던져서 6개 앞면이 나올 확률2.0148
# 동전을 10 번 던져서 7개 앞면이 나올 확률2.0148
# 동전을 10 번 던져서 8개 앞면이 나올 확률2.0148
# 동전을 10 번 던져서 9개 앞면이 나올 확률2.0148
# 동전을 10 번 던져서 10개 앞면이 나올 확률2.0148
# 동전을 10 번 던져서 1개 앞면이 나올 확률2.0149
# 동전을 10 번 던져서 2개 앞면이 나올 확률2.015
# 동전을 10 번 던져서 3개 앞면이 나올 확률2.015
# 동전을 10 번 던져서 4개 앞면이 나올 확률2.015
# 동전을 10 번 던져서 5개 앞면이 나올 확률2.0151
# 동전을 10 번 던져서 6개 앞면이 나올 확률2.0151
# 동전을 10 번 던져서 7개 앞면이 나올 확률2.0151
# 동전을 10 번 던져서 8개 앞면이 나올 확률2.0152
# 동전을 10 번 던져서 9개 앞면이 나올 확률2.0152
# 동전을 10 번 던져서 10개 앞면이 나올 확률2.0153
# 동전을 10 번 던져서 1개 앞면이 나올 확률2.0153
# 동전을 10 번 던져서 2개 앞면이 나올 확률2.0154
# 동전을 10 번 던져서 3개 앞면이 나올 확률2.0155
# 동전을 10 번 던져서 4개 앞면이 나올 확률2.0155
# 동전을 10 번 던져서 5개 앞면이 나올 확률2.0156
# 동전을 10 번 던져서 6개 앞면이 나올 확률2.0156
# 동전을 10 번 던져서 7개 앞면이 나올 확률2.0157
# 동전을 10 번 던져서 8개 앞면이 나올 확률2.0158
# 동전을 10 번 던져서 9개 앞면이 나올 확률2.0159
# 동전을 10 번 던져서 10개 앞면이 나올 확률2.016
# 동전을 10 번 던져서 1개 앞면이 나올 확률2.0161
# 동전을 10 번 던져서 2개 앞면이 나올 확률2.0161
# 동전을 10 번 던져서 3개 앞면이 나올 확률2.0161
# 동전을 10 번 던져서 4개 앞면이 나올 확률2.0162
# 동전을 10 번 던져서 5개 앞면이 나올 확률2.0162
# 동전을 10 번 던져서 6개 앞면이 나올 확률2.0163
# 동전을 10 번 던져서 7개 앞면이 나올 확률2.0163
# 동전을 10 번 던져서 8개 앞면이 나올 확률2.0164
# 동전을 10 번 던져서 9개 앞면이 나올 확률2.0164
# 동전을 10 번 던져서 10개 앞면이 나올 확률2.0165
# 동전을 10 번 던져서 1개 앞면이 나올 확률2.0165
# 동전을 10 번 던져서 2개 앞면이 나올 확률2.0165
# 동전을 10 번 던져서 3개 앞면이 나올 확률2.0166
# 동전을 10 번 던져서 4개 앞면이 나올 확률2.0167
# 동전을 10 번 던져서 5개 앞면이 나올 확률2.0168
# 동전을 10 번 던져서 6개 앞면이 나올 확률2.0168
# 동전을 10 번 던져서 7개 앞면이 나올 확률2.0168
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-227-5c1e4510e58d> in <module>()
#      17                 print(f"동전을 10 번 던져서 {i}개 앞면이 나올 확률{cnt/10000}")
#      18
# ---> 19 Coin_Prob()
#
# <ipython-input-227-5c1e4510e58d> in __init__(self)
#      15                 if result == 'front':
#      16                     cnt += 1
# ---> 17                 print(f"동전을 10 번 던져서 {i}개 앞면이 나올 확률{cnt/10000}")
#      18
#      19 Coin_Prob()
#
# /usr/local/lib/python3.6/dist-packages/ipykernel/iostream.py in write(self, string)
#     398             is_child = (not self._is_master_process())
#     399             # only touch the buffer in the IO thread to avoid races
# --> 400             self.pub_thread.schedule(lambda : self._buffer.write(string))
#     401             if is_child:
#     402                 # newlines imply flush in subprocesses
#
# /usr/local/lib/python3.6/dist-packages/ipykernel/iostream.py in schedule(self, f)
#     201             self._events.append(f)
#     202             # wake event thread (message content is ignored)
# --> 203             self._event_pipe.send(b'')
#     204         else:
#     205             f()
#
# /usr/local/lib/python3.6/dist-packages/zmq/sugar/socket.py in send(self, data, flags, copy, track, routing_id, group)
#     489                                  copy_threshold=self.copy_threshold)
#     490             data.group = group
# --> 491         return super(Socket, self).send(data, flags=flags, copy=copy, track=track)
#     492
#     493     def send_multipart(self, msg_parts, flags=0, copy=True, track=False, **kwargs):
#
# zmq/backend/cython/socket.pyx in zmq.backend.cython.socket.Socket.send()
#
# zmq/backend/cython/socket.pyx in zmq.backend.cython.socket.Socket.send()
#
# zmq/backend/cython/socket.pyx in zmq.backend.cython.socket._send_copy()
#
# /usr/local/lib/python3.6/dist-packages/zmq/backend/cython/checkrc.pxd in zmq.backend.cython.checkrc._check_rc()
#
# KeyboardInterrupt:

# %%
import random

print("앞면의 확률을 알아봅시다!")

want_num = int(input("몇번의 앞면의 확률을 알고 싶습니까?: "))
cont_num = int(input("몇번 던져보고 싶습니까?: "))

class Coin_Prob():

    def __init__(self, num):
        coin = ['front', 'back']
        cnt = 0
        print('동전 던지기를 시작하겠습니다.')
        
        for e in range(1, 10000):
            a=[]
            for i in range(1, cont_num+1):
                result = random.choice(coin)
                a.append(result)
                
            if a.count('front') == num:
                cnt += 1
        print(f"동전을 {cont_num}번 던져서 {want_num}개 앞면이 나올 확률{cnt/10000}")

Coin_Prob(want_num)
# Out:
# 앞면의 확률을 알아봅시다!
# 몇번의 앞면의 확률을 알고 싶습니까?: 5
# 몇번 던져보고 싶습니까?: 10
# 동전 던지기를 시작하겠습니다.
# 동전을 10번 던져서 5개 앞면이 나올 확률0.2525
